# %%
from sdgx.data_connectors.dataframe_connector import DataFrameConnector
from sdgx.data_connectors.base import DataConnector
from sdgx.data_models.metadata import Metadata
from sdgx.data_processors.base import DataProcessor
from sdgx.data_processors.manager import DataProcessorManager
import pandas as pd
from typing_extensions import Generator
import numpy as np
from sdgx.data_loader import DataLoader
from sdgx.data_connectors.generator_connector import GeneratorConnector

import faker

ff = faker.Faker()
df = pd.concat([
        pd.DataFrame([ff.date() for i in range(15000)], columns=['date']),
        pd.DataFrame([*np.linspace(0, 1, 15000), None], columns=['x']),
        pd.DataFrame([*np.linspace(0, 1, 10000), *([np.nan] * 5000)], columns=['y'])
    ], axis=1)
def gener():
    yield df.copy()

data_processors_manager = DataProcessorManager()
data_processors = data_processors_manager.registed_default_processor_list
data_processors = [
    (
        d if isinstance(d, DataProcessor) else data_processors_manager.init_data_processor(d)
    )
    for d in data_processors
]

def test_GeneratorConnector():
    dataconnector = GeneratorConnector(gener)
    dataloader = DataLoader(dataconnector)
    metadata = Metadata.from_dataloader(dataloader)
    metadata.datetime_columns = ["date"]
    metadata.discrete_columns = []
    metadata.datetime_format = {
        "date": "%Y-%m-%d"
    }
    for d in data_processors:
        d.fit(metadata=metadata, tabular_data=dataloader)
    def chunk_generator() -> Generator[pd.DataFrame, None, None]:
        for chunk in dataloader.iter():
            for d in data_processors:
                chunk = d.convert(chunk)
            yield chunk
    processed_dataloader = DataLoader(
        GeneratorConnector(chunk_generator),
        identity=dataloader.identity
    )
    processed_dataloader.load_all()
    
def test_DataFrameConnector():
    dataconnector = DataFrameConnector(df)
    dataloader = DataLoader(dataconnector)
    metadata = Metadata.from_dataloader(dataloader)
    metadata.datetime_columns = ["date"]
    metadata.discrete_columns = []
    metadata.datetime_format = {
        "date": "%Y-%m-%d"
    }
    for d in data_processors:
        d.fit(metadata=metadata, tabular_data=dataloader)
        
    data = dataloader.load_all()
    for d in data_processors:
        data = d.convert(data)
    dataconnector.reset_df(data)
    return dataloader.load_all(), data

# %%
d1, d2 = test_DataFrameConnector()
# Out:
# 2024-11-23 14:22:58.185 | INFO     | sdgx.data_models.metadata:from_dataloader:294 - Inspecting metadata...
# 2024-11-23 14:22:58.858 | INFO     | sdgx.data_models.metadata:update_primary_key:508 - Primary Key updated: set().
# 2024-11-23 14:22:58.859 | INFO     | sdgx.data_processors.transformers.specific_combination:fit:70 - Fit data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-23 14:22:58.859 | INFO     | sdgx.data_processors.transformers.fixed_combination:fit:94 - Fit data using FixedCombinationTransformer(not existed)... Finished (No action).
# 2024-11-23 14:22:58.860 | INFO     | sdgx.data_processors.transformers.nan:fit:81 - NonValueTransformer Fitted.
# 2024-11-23 14:22:58.861 | INFO     | sdgx.data_processors.transformers.nan:fit:97 - NonValueTransformer get int columns: set().
# 2024-11-23 14:22:58.862 | INFO     | sdgx.data_processors.transformers.nan:fit:106 - NonValueTransformer get float columns: {'y', 'x'}.
# 2024-11-23 14:22:58.862 | INFO     | sdgx.data_processors.transformers.nan:fit:111 - NonValueTransformer get column list from metadata: ['date', 'x', 'y'].
# 2024-11-23 14:22:58.863 | INFO     | sdgx.data_processors.transformers.outlier:fit:76 - OutlierTransformer Fitted.
# 2024-11-23 14:22:58.863 | INFO     | sdgx.data_processors.formatters.int:fit:43 - IntValueFormatter Fitted.
# 2024-11-23 14:22:58.864 | INFO     | sdgx.data_processors.formatters.datetime:fit:84 - DatetimeFormatter Fitted.
# 2024-11-23 14:22:58.864 | INFO     | sdgx.data_processors.transformers.const:fit:53 - ConstValueTransformer Fitted.
# 2024-11-23 14:22:58.865 | INFO     | sdgx.data_processors.filter.positive_negative:fit:58 - PositiveNegativeFilter Fitted.
# 2024-11-23 14:22:58.865 | INFO     | sdgx.data_processors.transformers.empty:fit:57 - EmptyTransformer Fitted.
# 2024-11-23 14:22:58.866 | INFO     | sdgx.data_processors.transformers.column_order:fit:44 - ColumnOrderTransformer Fitted.
# 2024-11-23 14:22:58.867 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-23 14:22:58.867 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:156 - Converting data using FixedCombinationTransformer(not existed)... Finished (No action).
# 2024-11-23 14:22:58.867 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-11-23 14:22:58.869 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-11-23 14:22:58.870 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-11-23 14:22:58.875 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-11-23 14:22:58.875 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-11-23 14:22:58.876 | INFO     | sdgx.data_processors.formatters.datetime:convert:106 - Converting data using DatetimeFormatter...
# 2024-11-23 14:22:58.954 | WARNING  | sdgx.data_processors.formatters.datetime:datetime_formatter:137 - An error occured when convert str to timestamp time data 'NAN_VALUE' does not match format '%Y-%m-%d', we set as mean.
# 2024-11-23 14:22:58.954 | WARNING  | sdgx.data_processors.formatters.datetime:datetime_formatter:138 - Input parameters: (NAN_VALUE, %Y-%m-%d)
# 2024-11-23 14:22:58.955 | WARNING  | sdgx.data_processors.formatters.datetime:datetime_formatter:139 - Input type: (<class 'str'>, <class 'str'>)
# 2024-11-23 14:22:58.957 | INFO     | sdgx.data_processors.formatters.datetime:convert:112 - Converting data using DatetimeFormatter... Finished.
# 2024-11-23 14:22:58.957 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-11-23 14:22:58.958 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-11-23 14:22:58.959 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-11-23 14:22:58.960 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-11-23 14:22:58.960 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-11-23 14:22:58.961 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-11-23 14:22:58.961 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).

# %%
d1
# Out:
#                date         x       y
# 0      1.610035e+09  0.000000  0.0000
# 1      1.537027e+09  0.000067  0.0001
# 2      1.086883e+09  0.000133  0.0002
# 3      1.601309e+09  0.000200  0.0003
# 4      1.239120e+09  0.000267  0.0004
# ...             ...       ...     ...
# 14996  8.618976e+08  0.999800  0.0000
# 14997  1.079712e+08  0.999867  0.0000
# 14998  1.305043e+09  0.999933  0.0000
# 14999  8.876448e+08  1.000000  0.0000
# 15000  8.636441e+08  0.000000  0.0000
#
# [15001 rows x 3 columns]

# %%
d2
# Out:
#                date         x       y
# 0      1.610035e+09  0.000000  0.0000
# 1      1.537027e+09  0.000067  0.0001
# 2      1.086883e+09  0.000133  0.0002
# 3      1.601309e+09  0.000200  0.0003
# 4      1.239120e+09  0.000267  0.0004
# ...             ...       ...     ...
# 14996  8.618976e+08  0.999800  0.0000
# 14997  1.079712e+08  0.999867  0.0000
# 14998  1.305043e+09  0.999933  0.0000
# 14999  8.876448e+08  1.000000  0.0000
# 15000  8.636441e+08  0.000000  0.0000
#
# [15001 rows x 3 columns]

# %%
test_GeneratorConnector()
# Out:
# 2024-11-23 14:18:03.854 | INFO     | sdgx.data_models.metadata:from_dataloader:294 - Inspecting metadata...
# 2024-11-23 14:18:04.513 | INFO     | sdgx.data_models.metadata:update_primary_key:508 - Primary Key updated: set().
# 2024-11-23 14:18:04.513 | INFO     | sdgx.data_processors.transformers.specific_combination:fit:70 - Fit data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-23 14:18:04.514 | INFO     | sdgx.data_processors.transformers.fixed_combination:fit:94 - Fit data using FixedCombinationTransformer(not existed)... Finished (No action).
# 2024-11-23 14:18:04.514 | INFO     | sdgx.data_processors.transformers.nan:fit:81 - NonValueTransformer Fitted.
# 2024-11-23 14:18:04.515 | INFO     | sdgx.data_processors.transformers.nan:fit:97 - NonValueTransformer get int columns: set().
# 2024-11-23 14:18:04.515 | INFO     | sdgx.data_processors.transformers.nan:fit:106 - NonValueTransformer get float columns: {'y', 'x'}.
# 2024-11-23 14:18:04.516 | INFO     | sdgx.data_processors.transformers.nan:fit:111 - NonValueTransformer get column list from metadata: ['date', 'x', 'y'].
# 2024-11-23 14:18:04.516 | INFO     | sdgx.data_processors.transformers.outlier:fit:76 - OutlierTransformer Fitted.
# 2024-11-23 14:18:04.517 | INFO     | sdgx.data_processors.formatters.int:fit:43 - IntValueFormatter Fitted.
# 2024-11-23 14:18:04.517 | INFO     | sdgx.data_processors.formatters.datetime:fit:84 - DatetimeFormatter Fitted.
# 2024-11-23 14:18:04.517 | INFO     | sdgx.data_processors.transformers.const:fit:53 - ConstValueTransformer Fitted.
# 2024-11-23 14:18:04.518 | INFO     | sdgx.data_processors.filter.positive_negative:fit:58 - PositiveNegativeFilter Fitted.
# 2024-11-23 14:18:04.518 | INFO     | sdgx.data_processors.transformers.empty:fit:57 - EmptyTransformer Fitted.
# 2024-11-23 14:18:04.518 | INFO     | sdgx.data_processors.transformers.column_order:fit:44 - ColumnOrderTransformer Fitted.
# 2024-11-23 14:18:04.523 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-23 14:18:04.523 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:156 - Converting data using FixedCombinationTransformer(not existed)... Finished (No action).
# 2024-11-23 14:18:04.524 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-11-23 14:18:04.526 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-11-23 14:18:04.526 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-11-23 14:18:04.529 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-11-23 14:18:04.529 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-11-23 14:18:04.530 | INFO     | sdgx.data_processors.formatters.datetime:convert:106 - Converting data using DatetimeFormatter...
# 2024-11-23 14:18:04.584 | INFO     | sdgx.data_processors.formatters.datetime:convert:112 - Converting data using DatetimeFormatter... Finished.
# 2024-11-23 14:18:04.585 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-11-23 14:18:04.586 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-11-23 14:18:04.587 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-11-23 14:18:04.587 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-11-23 14:18:04.588 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-11-23 14:18:04.589 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-11-23 14:18:04.589 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-11-23 14:18:04.606 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-23 14:18:04.607 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:156 - Converting data using FixedCombinationTransformer(not existed)... Finished (No action).
# 2024-11-23 14:18:04.607 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-11-23 14:18:04.609 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-11-23 14:18:04.609 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-11-23 14:18:04.611 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-11-23 14:18:04.611 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-11-23 14:18:04.612 | INFO     | sdgx.data_processors.formatters.datetime:convert:106 - Converting data using DatetimeFormatter...
# 2024-11-23 14:18:04.637 | WARNING  | sdgx.data_processors.formatters.datetime:datetime_formatter:137 - An error occured when convert str to timestamp time data 'NAN_VALUE' does not match format '%Y-%m-%d', we set as mean.
# 2024-11-23 14:18:04.638 | WARNING  | sdgx.data_processors.formatters.datetime:datetime_formatter:138 - Input parameters: (NAN_VALUE, %Y-%m-%d)
# 2024-11-23 14:18:04.638 | WARNING  | sdgx.data_processors.formatters.datetime:datetime_formatter:139 - Input type: (<class 'str'>, <class 'str'>)
# 2024-11-23 14:18:04.639 | INFO     | sdgx.data_processors.formatters.datetime:convert:112 - Converting data using DatetimeFormatter... Finished.
# 2024-11-23 14:18:04.640 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-11-23 14:18:04.641 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-11-23 14:18:04.641 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-11-23 14:18:04.642 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-11-23 14:18:04.642 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-11-23 14:18:04.643 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-11-23 14:18:04.643 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
