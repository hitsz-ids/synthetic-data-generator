# %%
from sdgx.data_connectors.csv_connector import CsvConnector
from sdgx.models.ml.single_table.ctgan import CTGANSynthesizerModel
from sdgx.synthesizer import Synthesizer
# from sdgx.utils import download_demo_data

# %%
from test_20_tables import fetch_data_from_sqlite, Metadata

metadata, tables = fetch_data_from_sqlite()
metadata = Metadata(metadata)
metadata.get_tables()
# Out:
# ['Student',
#  'Professor',
#  'Course',
#  'Department',
#  'Enrollment',
#  'Assignment',
#  'Submission',
#  'Schedule',
#  'Major',
#  'Textbook',
#  'CourseTextbook',
#  'Library',
#  'Book',
#  'BookLoan',
#  'ResearchGroup',
#  'ResearchProject',
#  'ProjectMember',
#  'Lab',
#  'LabEquipment',
#  'EquipmentMaintenance']

# %%
import pandas as pd
result_table = tables["BookLoan"]
x_table = ["Book", "Library", "Student", "Enrollment", "Submission"]
x_key = ['book_id', "library_id", "student_id", "student_id","student_id"]
x_how = ['outer', 'outer', "outer", 'outer', "outer"]
print(f"{len(result_table)=}")
for i, x_table_name in enumerate(x_table):
    result_table = pd.merge(result_table, tables[x_table_name], on=x_key[i], how=x_how[i])
    print(f"{len(result_table)=}")
print(len(result_table.columns))
result_table
# Out:
# len(result_table)=10000
# len(result_table)=10000
# len(result_table)=10000
# len(result_table)=13684
# len(result_table)=18813
# len(result_table)=26838
# 23
#        loan_id  book_id  student_id   loan_date return_date        title  \
# 0          1.0      1.0        5068  2024-07-19  2025-07-30  Model bank.
# 1          1.0      1.0        5068  2024-07-19  2025-07-30  Model bank.
# 2          1.0      1.0        5068  2024-07-19  2025-07-30  Model bank.
# 3          1.0      1.0        5068  2024-07-19  2025-07-30  Model bank.
# 4          1.0      1.0        5068  2024-07-19  2025-07-30  Model bank.
# ...        ...      ...         ...         ...         ...          ...
# 26833      NaN      NaN        9994         NaN         NaN          NaN
# 26834      NaN      NaN        9996         NaN         NaN          NaN
# 26835      NaN      NaN        9996         NaN         NaN          NaN
# 26836      NaN      NaN        9996         NaN         NaN          NaN
# 26837      NaN      NaN        9998         NaN         NaN          NaN
#
#             author               isbn  library_id                name_x  ...  \
# 0      Ricky Brown  978-1-4017-1762-9         1.0  Wilson Group Library  ...
# 1      Ricky Brown  978-1-4017-1762-9         1.0  Wilson Group Library  ...
# 2      Ricky Brown  978-1-4017-1762-9         1.0  Wilson Group Library  ...
# 3      Ricky Brown  978-1-4017-1762-9         1.0  Wilson Group Library  ...
# 4      Ricky Brown  978-1-4017-1762-9         1.0  Wilson Group Library  ...
# ...            ...                ...         ...                   ...  ...
# 26833          NaN                NaN         NaN                   NaN  ...
# 26834          NaN                NaN         NaN                   NaN  ...
# 26835          NaN                NaN         NaN                   NaN  ...
# 26836          NaN                NaN         NaN                   NaN  ...
# 26837          NaN                NaN         NaN                   NaN  ...
#
#       date_of_birth major enrollment_id course_id     semester  grade_x  \
# 0        2003-01-27  1262        5758.0    9618.0    Fall 2022        C
# 1        2003-01-27  1262        5758.0    9618.0    Fall 2022        C
# 2        2003-01-27  1262        5758.0    9618.0    Fall 2022        C
# 3        2003-01-27  1262        9382.0    5777.0  Summer 2023        A
# 4        2003-01-27  1262        9382.0    5777.0  Summer 2023        A
# ...             ...   ...           ...       ...          ...      ...
# 26833    1994-05-08  6802        6944.0    1428.0    Fall 2021        C
# 26834    2001-10-16  8561           NaN       NaN          NaN      NaN
# 26835    2001-10-16  8561           NaN       NaN          NaN      NaN
# 26836    2001-10-16  8561           NaN       NaN          NaN      NaN
# 26837    1996-10-11  8365           NaN       NaN          NaN      NaN
#
#        submission_id assignment_id      submission_date  grade_y
# 0             2462.0        9937.0  2022-10-18 02:02:31        B
# 1             3984.0        4403.0  2022-11-15 20:13:23        I
# 2             7851.0        6252.0  2022-07-31 08:44:12        A
# 3             2462.0        9937.0  2022-10-18 02:02:31        B
# 4             3984.0        4403.0  2022-11-15 20:13:23        I
# ...              ...           ...                  ...      ...
# 26833         7756.0        1543.0  2022-08-11 03:17:57        B
# 26834         1699.0        6848.0  2022-06-15 17:55:35        F
# 26835         6740.0        7011.0  2022-05-25 09:43:43        F
# 26836         9676.0        2748.0  2022-12-26 02:38:34        A
# 26837            NaN           NaN                  NaN      NaN
#
# [26838 rows x 23 columns]

# %%
result_table.to_csv("test_10k.csv")
dataset_csv = "test_10k.csv"

# %%
# This will download demo data to ./dataset
#dataset_csv = download_demo_data()

# Create data connector for csv file
data_connector = CsvConnector(path=dataset_csv)

# Initialize synthesizer, use CTGAN model
synthesizer = Synthesizer(
    model=CTGANSynthesizerModel(epochs=1),  # For quick demo
    data_connector=data_connector,
)
# Out:
# 2024-09-25 16:17:28.337 | INFO     | sdgx.synthesizer:__init__:106 - Using data processors: ['nonvaluetransformer', 'outliertransformer', 'emailgenerator', 'chnpiigenerator', 'intvalueformatter', 'datetimeformatter', 'constvaluetransformer', 'emptytransformer', 'columnordertransformer']

# %%
# Fit the model
synthesizer.fit()
# Out:
# 2024-09-25 16:19:30.649 | INFO     | sdgx.synthesizer:fit:292 - Fitting data processors...
# 2024-09-25 16:19:30.650 | INFO     | sdgx.data_processors.transformers.nan:fit:71 - NonValueTransformer Fitted.
# 2024-09-25 16:19:30.651 | INFO     | sdgx.data_processors.transformers.nan:fit:87 - NonValueTransformer get int columns: {'submission_id', 'course_id', 'loan_id', 'library_id', 'student_id', 'book_id', 'enrollment_id', 'assignment_id', 'major'}.
# 2024-09-25 16:19:30.652 | INFO     | sdgx.data_processors.transformers.nan:fit:96 - NonValueTransformer get float columns: set().
# 2024-09-25 16:19:30.652 | INFO     | sdgx.data_processors.transformers.nan:fit:101 - NonValueTransformer get column list from metadata: ['Unnamed: 0', 'loan_id', 'book_id', 'student_id', 'loan_date', 'return_date', 'title', 'author', 'isbn', 'library_id', 'name_x', 'location', 'name_y', 'email', 'date_of_birth', 'major', 'enrollment_id', 'course_id', 'semester', 'grade_x', 'submission_id', 'assignment_id', 'submission_date', 'grade_y'].
# 2024-09-25 16:19:30.653 | INFO     | sdgx.data_processors.transformers.outlier:fit:70 - OutlierTransformer Fitted.
# 2024-09-25 16:19:30.653 | INFO     | sdgx.data_processors.formatters.int:fit:40 - IntValueFormatter Fitted.
# 2024-09-25 16:19:30.654 | WARNING  | sdgx.data_processors.formatters.datetime:fit:70 - Column return_date has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-09-25 16:19:30.654 | WARNING  | sdgx.data_processors.formatters.datetime:fit:70 - Column submission_date has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-09-25 16:19:30.655 | WARNING  | sdgx.data_processors.formatters.datetime:fit:70 - Column date_of_birth has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-09-25 16:19:30.655 | WARNING  | sdgx.data_processors.formatters.datetime:fit:70 - Column loan_date has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-09-25 16:19:30.655 | INFO     | sdgx.data_processors.formatters.datetime:fit:77 - DatetimeFormatter Fitted.
# 2024-09-25 16:19:30.656 | INFO     | sdgx.data_processors.transformers.const:fit:49 - ConstValueTransformer Fitted.
# 2024-09-25 16:19:30.656 | INFO     | sdgx.data_processors.transformers.empty:fit:54 - EmptyTransformer Fitted.
# 2024-09-25 16:19:30.657 | INFO     | sdgx.data_processors.transformers.column_order:fit:41 - ColumnOrderTransformer Fitted.
# 2024-09-25 16:19:30.657 | INFO     | sdgx.synthesizer:fit:301 - Fitted 9 data processors in  0.006979942321777344s.
# 2024-09-25 16:19:30.657 | INFO     | sdgx.synthesizer:fit:311 - Initializing processed data loader...
# 2024-09-25 16:19:30.672 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-09-25 16:19:30.679 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-09-25 16:19:30.680 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-09-25 16:19:30.700 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-09-25 16:19:30.704 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-09-25 16:19:30.704 | INFO     | sdgx.data_processors.formatters.datetime:convert:89 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-09-25 16:19:30.705 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-09-25 16:19:30.706 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-09-25 16:19:30.706 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-09-25 16:19:30.706 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-09-25 16:19:30.706 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-09-25 16:19:30.706 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-09-25 16:19:30.744 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-09-25 16:19:30.751 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-09-25 16:19:30.752 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-09-25 16:19:30.771 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-09-25 16:19:30.775 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-09-25 16:19:30.775 | INFO     | sdgx.data_processors.formatters.datetime:convert:89 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-09-25 16:19:30.776 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-09-25 16:19:30.778 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-09-25 16:19:30.779 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-09-25 16:19:30.779 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-09-25 16:19:30.780 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-09-25 16:19:30.780 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-09-25 16:19:30.807 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-09-25 16:19:30.814 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-09-25 16:19:30.814 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-09-25 16:19:30.827 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# {'primary_keys': {'Unnamed: 0'}, 'column_list': ['Unnamed: 0', 'loan_id', 'book_id', 'student_id', 'loan_date', 'return_date', 'title', 'author', 'isbn', 'library_id', 'name_x', 'location', 'name_y', 'email', 'date_of_birth', 'major', 'enrollment_id', 'course_id', 'semester', 'grade_x', 'submission_id', 'assignment_id', 'submission_date', 'grade_y'], 'column_inspect_level': {'id_columns': 20, 'email_columns': 30, 'china_mainland_id_columns': 30, 'china_mainland_mobile_phone_columns': 30, 'const_columns': 80, 'datetime_columns': 20, 'china_mainland_address_columns': 30, 'english_name_columns': 40, 'chinese_company_name_columns': 40, 'unified_social_credit_code_columns': 30, 'empty_columns': 90, 'discrete_columns': 10, 'int_columns': 10, 'float_columns': 10, 'china_mainland_postcode_columns': 20, 'chinese_name_columns': 40, 'bool_columns': 10}, 'pii_columns': {'name_y', 'title', 'email', 'author'}, 'id_columns': {'Unnamed: 0'}, 'int_columns': {'Unnamed: 0', 'submission_id', 'course_id', 'loan_id', 'library_id', 'student_id', 'book_id', 'enrollment_id', 'assignment_id', 'major'}, 'float_columns': set(), 'bool_columns': set(), 'discrete_columns': {'return_date', 'submission_date', 'date_of_birth', 'location', 'grade_y', 'loan_date', 'name_y', 'author', 'grade_x', 'name_x', 'email', 'title', 'semester', 'isbn'}, 'datetime_columns': {'return_date', 'submission_date', 'date_of_birth', 'loan_date'}, 'const_columns': set(), 'datetime_format': {}, 'numeric_format': {'positive': ['Unnamed: 0', 'assignment_id', 'book_id', 'course_id', 'enrollment_id', 'library_id', 'loan_id', 'major', 'student_id', 'submission_id'], 'negative': []}, 'version': '1.0'}
# 2024-09-25 16:19:30.830 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-09-25 16:19:30.830 | INFO     | sdgx.data_processors.formatters.datetime:convert:89 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-09-25 16:19:30.831 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-09-25 16:19:30.832 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-09-25 16:19:30.832 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-09-25 16:19:30.832 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-09-25 16:19:30.832 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-09-25 16:19:30.833 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-09-25 16:19:30.858 | INFO     | sdgx.synthesizer:fit:318 - Initialized processed data loader in 0.20061182975769043s
# 2024-09-25 16:19:30.859 | INFO     | sdgx.synthesizer:fit:320 - Model fit Started...
# 2024-09-25 16:19:30.869 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-09-25 16:19:30.876 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-09-25 16:19:30.877 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-09-25 16:19:30.895 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-09-25 16:19:30.899 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-09-25 16:19:30.899 | INFO     | sdgx.data_processors.formatters.datetime:convert:89 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-09-25 16:19:30.900 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-09-25 16:19:30.901 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-09-25 16:19:30.903 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-09-25 16:19:30.904 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-09-25 16:19:30.904 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-09-25 16:19:30.904 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-09-25 16:19:30.905 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:234 - Fitting model's transformer...
# 2024-09-25 16:19:30.940 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-09-25 16:19:30.947 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-09-25 16:19:30.948 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-09-25 16:19:30.971 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-09-25 16:19:30.975 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-09-25 16:19:30.975 | INFO     | sdgx.data_processors.formatters.datetime:convert:89 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-09-25 16:19:30.976 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-09-25 16:19:30.977 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-09-25 16:19:30.977 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-09-25 16:19:30.978 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-09-25 16:19:30.978 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-09-25 16:19:30.978 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-09-25 16:19:46.832 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:236 - Transforming data...
# 2024-09-25 16:19:46.870 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-09-25 16:19:46.877 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-09-25 16:19:46.877 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-09-25 16:19:46.899 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-09-25 16:19:46.903 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-09-25 16:19:46.904 | INFO     | sdgx.data_processors.formatters.datetime:convert:89 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-09-25 16:19:46.905 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-09-25 16:19:46.905 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-09-25 16:19:46.906 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-09-25 16:19:46.906 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-09-25 16:19:46.907 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-09-25 16:19:46.908 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-09-25 16:19:47.516 | WARNING  | sdgx.models.components.optimize.sdv_ctgan.data_transformer:_parallel_transform:175 - Using generator_unordered in joblib, time to remove this exception!
# 2024-09-25 16:20:40.137 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:239 - Sampling data.
# C:\Users\Elvin\Desktop\GitHub\synthetic-data-generator\sdgx\models\components\optimize\sdv_ctgan\data_sampler.py:69: RuntimeWarning: invalid value encountered in log
#   category_freq = np.log(category_freq + 1)
# 2024-09-25 16:21:25.265 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:244 - Initialize Generator.
# 2024-09-25 16:21:42.037 | INFO     | sdgx.models.ml.single_table.ctgan:fit:219 - CTGAN prefit finished, start CTGAN training.
# 2024-09-25 16:21:42.040 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:261 - Fit using data_size:26838, data_dim: 73260.
# 2024-09-25 16:21:45.107 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:287 - Starting model training, epochs: 1

# %%
# Sample
sampled_data = synthesizer.sample(10000)
print(sampled_data)
