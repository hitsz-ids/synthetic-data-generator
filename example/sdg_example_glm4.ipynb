# %% [markdown]
# <div align="center">
#   <img src="https://github.com/hitsz-ids/synthetic-data-generator/blob/main/assets/sdg_logo.png?raw=true" width="400" >
# </div>
# <div align="center">

# %% [markdown]
# # 🚀 Synthetic data generation without Raw Data using LLM
#
#
#
#
# The Synthetic Data Generator (SDG) is a specialized framework designed to generate high-quality structured tabular data. It incorporates a wide range of single-table, multi-table data synthesis algorithms and LLM-based synthetic data generation models.
#
# Synthetic data, generated by machines using real data, metadata, and algorithms, does not contain any sensitive information, yet it retains the essential characteristics of the original data. There is no direct correlation between synthetic data and real data, making it exempt from privacy regulations such as GDPR and ADPPA. This eliminates the risk of privacy breaches in practical applications.

# %%
from sdgx.models.LLM.single_table.gpt import *

# %%
class SingleTableGLMModel(SingleTableGPTModel):
    
    def ask_gpt(self, question, model=None):
        """
        Sends a question to the GPT model.

        Args:
            question (str): The question to ask.
            model (str): The GPT model to use. Defaults to None.

        Returns:
            str: The response from the GPT model.

        Raises:
            SynthesizerInitError: If the check method fails.
        """
        self.check()
        api_key = self.openai_API_key
        if model:
            model = model
        else:
            model = self.gpt_model
        openai.api_key = api_key
        client = openai.OpenAI(base_url=self.openai_API_url,
                               api_key=api_key)
        logger.info(f"Ask GPT with temperature = {self.temperature}.")
        response = client.chat.completions.create(
            model=model,
            messages=[
                {
                    "role": "user",
                    "content": question,
                },
            ],

            temperature=self.temperature,
            max_tokens=self.max_tokens,
            timeout=self.timeout,
        )
        logger.info("Ask GPT Finished.")
        # store response
        self._responses.append(response)
        # return the content of the gpt response
        return response.choices[0].message.content

# %%
# install dependencies
# !pip install sdgx
# OR
# !pip install git+https://github.com/hitsz-ids/synthetic-data-generator.git
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting git+https://github.com/hitsz-ids/synthetic-data-generator.git
#   Cloning https://github.com/hitsz-ids/synthetic-data-generator.git to /private/var/folders/sj/9gkwxdgs4h3ck3kytmdgk4240000gn/T/pip-req-build-2ehjkri6
#   Running command git clone --filter=blob:none --quiet https://github.com/hitsz-ids/synthetic-data-generator.git /private/var/folders/sj/9gkwxdgs4h3ck3kytmdgk4240000gn/T/pip-req-build-2ehjkri6
#   Resolved https://github.com/hitsz-ids/synthetic-data-generator.git to commit d60da3ff1f0e84efa20d9d66c0542f8a41492156
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (8.1.7)
# Requirement already satisfied: cloudpickle in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (3.0.0)
# Requirement already satisfied: faker>=10 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (25.5.0)
# Requirement already satisfied: importlib-metadata in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (7.1.0)
# Requirement already satisfied: joblib>=1.4.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.4.2)
# Requirement already satisfied: loguru in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (0.7.2)
# Requirement already satisfied: matplotlib in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (3.9.0)
# Requirement already satisfied: numpy in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.26.4)
# Requirement already satisfied: openai>=1.10.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.31.1)
# Requirement already satisfied: pandas in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (2.0.3)
# Requirement already satisfied: pluggy in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.5.0)
# Requirement already satisfied: pyarrow in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (16.1.0)
# Requirement already satisfied: pydantic>=2 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (2.7.3)
# Requirement already satisfied: python-dotenv in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.0.1)
# Requirement already satisfied: pyyaml in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (6.0.1)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.5.0)
# Requirement already satisfied: scipy in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.13.1)
# Requirement already satisfied: table-evaluator in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (1.6.1)
# Requirement already satisfied: torch>=2 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sdgx==0.2.1.dev0) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from faker>=10->sdgx==0.2.1.dev0) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from openai>=1.10.0->sdgx==0.2.1.dev0) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from openai>=1.10.0->sdgx==0.2.1.dev0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from openai>=1.10.0->sdgx==0.2.1.dev0) (0.27.0)
# Requirement already satisfied: sniffio in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from openai>=1.10.0->sdgx==0.2.1.dev0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from openai>=1.10.0->sdgx==0.2.1.dev0) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from openai>=1.10.0->sdgx==0.2.1.dev0) (4.12.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from pydantic>=2->sdgx==0.2.1.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from pydantic>=2->sdgx==0.2.1.dev0) (2.18.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from scikit-learn<2,>=0.24->sdgx==0.2.1.dev0) (3.5.0)
# Requirement already satisfied: filelock in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from torch>=2->sdgx==0.2.1.dev0) (3.14.0)
# Requirement already satisfied: sympy in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from torch>=2->sdgx==0.2.1.dev0) (1.12.1)
# Requirement already satisfied: networkx in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from torch>=2->sdgx==0.2.1.dev0) (3.3)
# Requirement already satisfied: jinja2 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from torch>=2->sdgx==0.2.1.dev0) (3.1.4)
# Requirement already satisfied: fsspec in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from torch>=2->sdgx==0.2.1.dev0) (2024.6.0)
# Requirement already satisfied: zipp>=0.5 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from importlib-metadata->sdgx==0.2.1.dev0) (3.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from matplotlib->sdgx==0.2.1.dev0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from matplotlib->sdgx==0.2.1.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from matplotlib->sdgx==0.2.1.dev0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from matplotlib->sdgx==0.2.1.dev0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from matplotlib->sdgx==0.2.1.dev0) (24.0)
# Requirement already satisfied: pillow>=8 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from matplotlib->sdgx==0.2.1.dev0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from matplotlib->sdgx==0.2.1.dev0) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from pandas->sdgx==0.2.1.dev0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from pandas->sdgx==0.2.1.dev0) (2024.1)
# Requirement already satisfied: psutil in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from table-evaluator->sdgx==0.2.1.dev0) (5.9.8)
# Requirement already satisfied: dython==0.7.3 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from table-evaluator->sdgx==0.2.1.dev0) (0.7.3)
# Requirement already satisfied: seaborn in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from table-evaluator->sdgx==0.2.1.dev0) (0.13.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from dython==0.7.3->table-evaluator->sdgx==0.2.1.dev0) (0.3.7)
# Requirement already satisfied: idna>=2.8 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.10.0->sdgx==0.2.1.dev0) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.10.0->sdgx==0.2.1.dev0) (1.2.1)
# Requirement already satisfied: certifi in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.10.0->sdgx==0.2.1.dev0) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.10.0->sdgx==0.2.1.dev0) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.10.0->sdgx==0.2.1.dev0) (0.14.0)
# Requirement already satisfied: six>=1.5 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from python-dateutil>=2.4->faker>=10->sdgx==0.2.1.dev0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from jinja2->torch>=2->sdgx==0.2.1.dev0) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/zhaoxuefeng/opt/miniconda3/envs/sdg/lib/python3.10/site-packages (from sympy->torch>=2->sdgx==0.2.1.dev0) (1.3.0)

# %% [markdown]
# We demonstrate with a single table synthetic example.
#
# # LLM-integrated synthetic data generation
#
# For a long time, LLM has been used to understand and generate various types of data.
#
# In fact, LLM also has certain capabilities in tabular data generation. LLM has some abilities that cannot be achieved by traditional (GAN-based models or statistical models) .

# %%
# please set your GLM4 key here:

GLM4_AI_KEY = "-"
GLM4_AI_BASE = 'http://192.168.8.126:8006/v1/'

# %%
# import packages

import pandas as pd
from sdgx.utils import download_demo_data
from sdgx.data_models.metadata import Metadata
from sdgx.models.LLM.single_table.gpt import SingleTableGPTModel

# read the demo data
# currently we use the well-known adult dataset as a example
data_path = download_demo_data()
df = pd.read_csv(data_path)
metadata = Metadata.from_dataframe(df)

# %% [markdown]
# # Synthetic data generation without Data
#
#
# Our `sdgx.models.LLM.single_table.gpt.SingleTableGPTModel` implements “Synthetic data generation without Raw Data”.
#
# No training data is required, synthetic data can be generated based on metadata data.
#
# ![LLM_Case_1](https://github.com/hitsz-ids/synthetic-data-generator/blob/main/assets/LLM_Case_1.gif?raw=true)

# %%
model = SingleTableGLMModel()
model.set_openAI_settings(GLM4_AI_BASE, GLM4_AI_KEY)
model.gpt_model = "glm4"

# %%
model.fit(metadata)
# this may take a while
sampled_data = model.sample(30)
# Out:
# 2024-06-07 16:01:56.035 | INFO     | sdgx.models.LLM.single_table.gpt:_fit_with_metadata:231 - Fitting model with metadata...
# 2024-06-07 16:01:56.036 | INFO     | sdgx.models.LLM.single_table.gpt:_fit_with_metadata:235 - Fitting model with metadata... Finished.
# 2024-06-07 16:01:56.037 | INFO     | sdgx.models.LLM.single_table.gpt:sample:388 - Sampling use GPT model ...
# 2024-06-07 16:01:56.038 | INFO     | sdgx.models.LLM.single_table.gpt:_sample_with_metadata:449 - Sampling with metadata.
# 2024-06-07 16:01:56.038 | INFO     | sdgx.models.LLM.base:_form_dataset_description:122 - No dataset_description given in current model.
# 2024-06-07 16:01:56.039 | INFO     | sdgx.models.LLM.base:_form_message_with_offtable_features:108 - No off_table_feature needed in current model.
# 2024-06-07 16:01:56.156 | INFO     | __main__:ask_gpt:26 - Ask GPT with temperature = 0.1.
# 2024-06-07 16:01:57.120 | INFO     | __main__:ask_gpt:40 - Ask GPT Finished.
# 2024-06-07 16:01:57.122 | INFO     | sdgx.models.LLM.single_table.gpt:extract_samples_from_response:360 - Extracting samples from response ...
# 2024-06-07 16:01:57.127 | INFO     | sdgx.models.LLM.single_table.gpt:extract_samples_from_response:372 - Extracting samples from response ... Finished, 0 extracted.
# 2024-06-07 16:01:57.132 | INFO     | sdgx.models.LLM.single_table.gpt:sample:398 - Sampling use GPT model ... Finished.

# %%
sampled_data
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, educational-num, marital-status, occupation, relationship, race, gender, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %% [markdown]
# View the original information returned by gpt through the `_responses` attribute.

# %%
model._responses
# Out:
# [ChatCompletion(id='7397f509-071b-41b3-9bca-c9093b55f228', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='is a file format used for LaTeX documents. It is not related to data generation or tabular data. Please provide the correct information or context for generating data samples.', role='assistant', function_call=None, tool_calls=None))], created=None, model='glm4', object='chat.completion', system_fingerprint=None, usage=None)]
