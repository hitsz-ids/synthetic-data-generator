# %% [markdown]
# 构造数据

# %%
from mycode.common import *
from multi_ctgan import MultiTableCTGAN
from mycode import dataset
db_path = dataset.Database.path_10k
x_args = dataset.XArgs.tables_12
try:
    multi_wrapper = MultiTableCTGAN(
    db_path=db_path,
    x_table=x_args.x_table,
    x_key=x_args.x_key,
    x_how=x_args.x_how
).init()
except ValueError as e:
    print(e.args[0])
    df = e.args[1]
    df[0]
# Out:
# 10000 10000 10000 10000 9999 10798 10798 10573 10573 20765 20765
# 20765 lines x 37 columns

# %%
multi_wrapper.join_tables
# Out:
#        BookLoan_TABLE_loan_id  REF_TABLE_book_id  REF_TABLE_student_id  \
# 0                          13                 13                  8472
# 1                        6750               6750                  8472
# 2                          13                 13                  8472
# 3                        6750               6750                  8472
# 4                          13                 13                  8472
# ...                       ...                ...                   ...
# 20760                    9961               9961                  3278
# 20761                    9998               9998                  3486
# 20762                    9998               9998                  3486
# 20763                    9999               9999                  2281
# 20764                    9999               9999                  2281
#
#       BookLoan_TABLE_loan_date BookLoan_TABLE_return_date  \
# 0                   2024-06-14                 2025-04-13
# 1                   2024-01-20                 2025-07-31
# 2                   2024-06-14                 2025-04-13
# 3                   2024-01-20                 2025-07-31
# 4                   2024-06-14                 2025-04-13
# ...                        ...                        ...
# 20760               2024-03-02                 2025-05-09
# 20761               2024-01-14                 2024-12-09
# 20762               2024-01-14                 2024-12-09
# 20763               2023-12-28                 2025-08-23
# 20764               2023-12-28                 2025-08-23
#
#               Book_TABLE_title    Book_TABLE_author    Book_TABLE_isbn  \
# 0            Edge result fall.         Robert Jones  978-0-688-77854-5
# 1              Trial movement.  Stephanie Schroeder  978-0-09-198217-1
# 2            Edge result fall.         Robert Jones  978-0-688-77854-5
# 3              Trial movement.  Stephanie Schroeder  978-0-09-198217-1
# 4            Edge result fall.         Robert Jones  978-0-688-77854-5
# ...                        ...                  ...                ...
# 20760             Never quite.          Sheila Pham  978-0-546-12288-6
# 20761  Listen interview world.        Richard Floyd  978-0-7738-9332-0
# 20762  Listen interview world.        Richard Floyd  978-0-7738-9332-0
# 20763   Challenge last suffer.       Robert Holland  978-1-67998-842-4
# 20764   Challenge last suffer.       Robert Holland  978-1-67998-842-4
#
#        REF_TABLE_library_id       Library_TABLE_name  ...  \
# 0                        13      James Group Library  ...
# 1                      6750       Harris PLC Library  ...
# 2                        13      James Group Library  ...
# 3                      6750       Harris PLC Library  ...
# 4                        13      James Group Library  ...
# ...                     ...                      ...  ...
# 20760                  9961  Wilkinson-Adams Library  ...
# 20761                  9998     Johnston Inc Library  ...
# 20762                  9998     Johnston Inc Library  ...
# 20763                  9999   Williams-Smith Library  ...
# 20764                  9999   Williams-Smith Library  ...
#
#          Textbook_TABLE_title Textbook_TABLE_author Textbook_TABLE_isbn  \
# 0      Young pressure speech.       Marcus Erickson   978-0-699-72473-9
# 1      Young pressure speech.       Marcus Erickson   978-0-699-72473-9
# 2                          A.       Donald Gonzales   978-0-499-67218-6
# 3                          A.       Donald Gonzales   978-0-499-67218-6
# 4      Young pressure speech.       Marcus Erickson   978-0-699-72473-9
# ...                       ...                   ...                 ...
# 20760             Moment top.            Maria King   978-1-00-272787-4
# 20761        Direction order.      Kenneth Shepherd   978-0-561-19675-6
# 20762        Direction order.      Kenneth Shepherd   978-0-561-19675-6
# 20763       Despite language.         Brandon Davis   978-0-696-73365-9
# 20764       Despite language.         Brandon Davis   978-0-696-73365-9
#
#       Schedule_TABLE_schedule_id REF_TABLE_professor_id  Schedule_TABLE_room  \
# 0                           3902                   6014                23142
# 1                           3902                   6014                23142
# 2                           3902                   6014                23142
# 3                           3902                   6014                23142
# 4                           5365                    124                  051
# ...                          ...                    ...                  ...
# 20760                       9383                   5656                 2439
# 20761                       5992                   1329                  012
# 20762                       5992                   1329                  012
# 20763                       3566                   8274                63893
# 20764                       3566                   8274                63893
#
#        Schedule_TABLE_time_slot Professor_TABLE_name  \
# 0                      20:01:34        Benjamin Cook
# 1                      20:01:34        Benjamin Cook
# 2                      20:01:34        Benjamin Cook
# 3                      20:01:34        Benjamin Cook
# 4                      11:09:08      Darryl Peterson
# ...                         ...                  ...
# 20760                  08:14:47           Karen Wolf
# 20761                  15:31:39       Debbie Griffin
# 20762                  15:31:39       Debbie Griffin
# 20763                  10:14:29    Brandon Cervantes
# 20764                  10:14:29    Brandon Cervantes
#
#             Professor_TABLE_email  Professor_TABLE_department
# 0             shawn60@example.net                        9590
# 1             shawn60@example.net                        9590
# 2             shawn60@example.net                        9590
# 3             shawn60@example.net                        9590
# 4        jessesanchez@example.net                        1767
# ...                           ...                         ...
# 20760      kylejacobs@example.com                          53
# 20761  patelalejandro@example.net                        1327
# 20762  patelalejandro@example.net                        1327
# 20763       iwilliams@example.com                         453
# 20764       iwilliams@example.com                         453
#
# [20765 rows x 37 columns]

# %%
# temp = multi_wrapper.tables_["Assignment"].rename(columns={"assignment_id": "Assignment_TABLE_assignment_id"}) 
# pd.merge(multi_wrapper.join_tables, temp, how='outer', on="REF_TABLE_assignment_id")

# %%
    # raise e
print(multi_wrapper.join_columns_map)
multi_wrapper.join_tables
# Out:
# {'BookLoan': {'BookLoan_TABLE_return_date': 'return_date', 'BookLoan_TABLE_loan_date': 'loan_date', 'BookLoan_TABLE_loan_id': 'loan_id', 'REF_TABLE_student_id': 'student_id', 'REF_TABLE_book_id': 'book_id'}, 'Book': {'Book_TABLE_isbn': 'isbn', 'Book_TABLE_title': 'title', 'Book_TABLE_author': 'author', 'REF_TABLE_library_id': 'library_id', 'REF_TABLE_book_id': 'book_id'}, 'Library': {'Library_TABLE_name': 'name', 'Library_TABLE_location': 'location', 'REF_TABLE_library_id': 'library_id'}, 'Student': {'Student_TABLE_date_of_birth': 'date_of_birth', 'Student_TABLE_email': 'email', 'Student_TABLE_major': 'major', 'Student_TABLE_name': 'name', 'REF_TABLE_student_id': 'student_id'}, 'Enrollment': {'Enrollment_TABLE_semester': 'semester', 'Enrollment_TABLE_grade': 'grade', 'Enrollment_TABLE_enrollment_id': 'enrollment_id', 'REF_TABLE_student_id': 'student_id', 'REF_TABLE_course_id': 'course_id'}, 'Submission': {'Submission_TABLE_submission_date': 'submission_date', 'Submission_TABLE_submission_id': 'submission_id', 'Submission_TABLE_assignment_id': 'assignment_id', 'Submission_TABLE_grade': 'grade', 'REF_TABLE_student_id': 'student_id'}, 'Course': {'Course_TABLE_title': 'title', 'Course_TABLE_department': 'department', 'Course_TABLE_credits': 'credits', 'REF_TABLE_course_id': 'course_id'}, 'CourseTextbook': {'REF_TABLE_textbook_id': 'textbook_id', 'REF_TABLE_course_id': 'course_id'}, 'Textbook': {'Textbook_TABLE_isbn': 'isbn', 'Textbook_TABLE_title': 'title', 'Textbook_TABLE_author': 'author', 'REF_TABLE_textbook_id': 'textbook_id'}, 'Schedule': {'Schedule_TABLE_room': 'room', 'Schedule_TABLE_time_slot': 'time_slot', 'Schedule_TABLE_schedule_id': 'schedule_id', 'REF_TABLE_course_id': 'course_id', 'REF_TABLE_professor_id': 'professor_id'}, 'Professor': {'Professor_TABLE_email': 'email', 'Professor_TABLE_department': 'department', 'Professor_TABLE_name': 'name', 'REF_TABLE_professor_id': 'professor_id'}}
#        BookLoan_TABLE_loan_id  REF_TABLE_book_id  REF_TABLE_student_id  \
# 0                          13                 13                  8472
# 1                        6750               6750                  8472
# 2                          13                 13                  8472
# 3                        6750               6750                  8472
# 4                          13                 13                  8472
# ...                       ...                ...                   ...
# 20760                    9961               9961                  3278
# 20761                    9998               9998                  3486
# 20762                    9998               9998                  3486
# 20763                    9999               9999                  2281
# 20764                    9999               9999                  2281
#
#       BookLoan_TABLE_loan_date BookLoan_TABLE_return_date  \
# 0                   2024-06-14                 2025-04-13
# 1                   2024-01-20                 2025-07-31
# 2                   2024-06-14                 2025-04-13
# 3                   2024-01-20                 2025-07-31
# 4                   2024-06-14                 2025-04-13
# ...                        ...                        ...
# 20760               2024-03-02                 2025-05-09
# 20761               2024-01-14                 2024-12-09
# 20762               2024-01-14                 2024-12-09
# 20763               2023-12-28                 2025-08-23
# 20764               2023-12-28                 2025-08-23
#
#               Book_TABLE_title    Book_TABLE_author    Book_TABLE_isbn  \
# 0            Edge result fall.         Robert Jones  978-0-688-77854-5
# 1              Trial movement.  Stephanie Schroeder  978-0-09-198217-1
# 2            Edge result fall.         Robert Jones  978-0-688-77854-5
# 3              Trial movement.  Stephanie Schroeder  978-0-09-198217-1
# 4            Edge result fall.         Robert Jones  978-0-688-77854-5
# ...                        ...                  ...                ...
# 20760             Never quite.          Sheila Pham  978-0-546-12288-6
# 20761  Listen interview world.        Richard Floyd  978-0-7738-9332-0
# 20762  Listen interview world.        Richard Floyd  978-0-7738-9332-0
# 20763   Challenge last suffer.       Robert Holland  978-1-67998-842-4
# 20764   Challenge last suffer.       Robert Holland  978-1-67998-842-4
#
#        REF_TABLE_library_id       Library_TABLE_name  ...  \
# 0                        13      James Group Library  ...
# 1                      6750       Harris PLC Library  ...
# 2                        13      James Group Library  ...
# 3                      6750       Harris PLC Library  ...
# 4                        13      James Group Library  ...
# ...                     ...                      ...  ...
# 20760                  9961  Wilkinson-Adams Library  ...
# 20761                  9998     Johnston Inc Library  ...
# 20762                  9998     Johnston Inc Library  ...
# 20763                  9999   Williams-Smith Library  ...
# 20764                  9999   Williams-Smith Library  ...
#
#          Textbook_TABLE_title Textbook_TABLE_author Textbook_TABLE_isbn  \
# 0      Young pressure speech.       Marcus Erickson   978-0-699-72473-9
# 1      Young pressure speech.       Marcus Erickson   978-0-699-72473-9
# 2                          A.       Donald Gonzales   978-0-499-67218-6
# 3                          A.       Donald Gonzales   978-0-499-67218-6
# 4      Young pressure speech.       Marcus Erickson   978-0-699-72473-9
# ...                       ...                   ...                 ...
# 20760             Moment top.            Maria King   978-1-00-272787-4
# 20761        Direction order.      Kenneth Shepherd   978-0-561-19675-6
# 20762        Direction order.      Kenneth Shepherd   978-0-561-19675-6
# 20763       Despite language.         Brandon Davis   978-0-696-73365-9
# 20764       Despite language.         Brandon Davis   978-0-696-73365-9
#
#       Schedule_TABLE_schedule_id REF_TABLE_professor_id  Schedule_TABLE_room  \
# 0                           3902                   6014                23142
# 1                           3902                   6014                23142
# 2                           3902                   6014                23142
# 3                           3902                   6014                23142
# 4                           5365                    124                  051
# ...                          ...                    ...                  ...
# 20760                       9383                   5656                 2439
# 20761                       5992                   1329                  012
# 20762                       5992                   1329                  012
# 20763                       3566                   8274                63893
# 20764                       3566                   8274                63893
#
#        Schedule_TABLE_time_slot Professor_TABLE_name  \
# 0                      20:01:34        Benjamin Cook
# 1                      20:01:34        Benjamin Cook
# 2                      20:01:34        Benjamin Cook
# 3                      20:01:34        Benjamin Cook
# 4                      11:09:08      Darryl Peterson
# ...                         ...                  ...
# 20760                  08:14:47           Karen Wolf
# 20761                  15:31:39       Debbie Griffin
# 20762                  15:31:39       Debbie Griffin
# 20763                  10:14:29    Brandon Cervantes
# 20764                  10:14:29    Brandon Cervantes
#
#             Professor_TABLE_email  Professor_TABLE_department
# 0             shawn60@example.net                        9590
# 1             shawn60@example.net                        9590
# 2             shawn60@example.net                        9590
# 3             shawn60@example.net                        9590
# 4        jessesanchez@example.net                        1767
# ...                           ...                         ...
# 20760      kylejacobs@example.com                          53
# 20761  patelalejandro@example.net                        1327
# 20762  patelalejandro@example.net                        1327
# 20763       iwilliams@example.com                         453
# 20764       iwilliams@example.com                         453
#
# [20765 rows x 37 columns]

# %%
from mycode.dataset import XMetaBuilder
multi_wrapper.build_metadata(builder=XMetaBuilder(x_args))
# Out:
# 2024-10-16 16:18:18.037 | INFO     | sdgx.data_models.metadata:from_dataloader:294 - Inspecting metadata...
# 2024-10-16 16:18:18.054 | DEBUG    | sdgx.manager:register:99 - Register for new model: subsetrelationshipinspector
# 2024-10-16 16:18:18.055 | DEBUG    | sdgx.manager:register:99 - Register for new model: emailinspector
# 2024-10-16 16:18:18.055 | DEBUG    | sdgx.manager:register:99 - Register for new model: chinamainlandidinspector
# 2024-10-16 16:18:18.056 | DEBUG    | sdgx.manager:register:99 - Register for new model: chinamainlandmobilephoneinspector
# 2024-10-16 16:18:18.056 | DEBUG    | sdgx.manager:register:99 - Register for new model: chinamainlandpostcode
# 2024-10-16 16:18:18.057 | DEBUG    | sdgx.manager:register:99 - Register for new model: chinamainlandunifiedsocialcreditcode
# 2024-10-16 16:18:18.058 | DEBUG    | sdgx.manager:register:99 - Register for new model: chinamainlandaddressinspector
# 2024-10-16 16:18:18.058 | DEBUG    | sdgx.manager:register:99 - Register for new model: chinesenameinspector
# 2024-10-16 16:18:18.058 | DEBUG    | sdgx.manager:register:99 - Register for new model: englishnameinspector
# 2024-10-16 16:18:18.059 | DEBUG    | sdgx.manager:register:99 - Register for new model: chinesecompanynameinspector
# 2024-10-16 16:18:18.059 | DEBUG    | sdgx.manager:register:99 - Register for new model: numericinspector
# 2024-10-16 16:18:18.059 | DEBUG    | sdgx.manager:register:99 - Register for new model: idinspector
# 2024-10-16 16:18:18.060 | DEBUG    | sdgx.manager:register:99 - Register for new model: emptyinspector
# 2024-10-16 16:18:18.060 | DEBUG    | sdgx.manager:register:99 - Register for new model: discreteinspector
# 2024-10-16 16:18:18.060 | DEBUG    | sdgx.manager:register:99 - Register for new model: datetimeinspector
# 2024-10-16 16:18:18.061 | DEBUG    | sdgx.manager:register:99 - Register for new model: constinspector
# 2024-10-16 16:18:18.061 | DEBUG    | sdgx.manager:register:99 - Register for new model: boolinspector
# 2024-10-16 16:18:23.511 | INFO     | sdgx.data_models.metadata:update_primary_key:503 - Primary Key updated: set().
# metadata.int_columns={'Course_TABLE_credits', 'Schedule_TABLE_room', 'Course_TABLE_department', 'REF_TABLE_student_id', 'REF_TABLE_course_id', 'Submission_TABLE_submission_id', 'BookLoan_TABLE_loan_id', 'Professor_TABLE_department', 'Schedule_TABLE_schedule_id', 'Enrollment_TABLE_enrollment_id', 'Submission_TABLE_assignment_id', 'REF_TABLE_textbook_id', 'REF_TABLE_library_id', 'REF_TABLE_book_id', 'Student_TABLE_major', 'REF_TABLE_professor_id'}
# metadata.float_columns=set()
# metadata.const_columns=set()
# metadata.bool_columns=set()
# metadata.discrete_columns={'Textbook_TABLE_isbn', 'Enrollment_TABLE_semester', 'Textbook_TABLE_author', 'Professor_TABLE_name', 'Student_TABLE_email', 'Library_TABLE_name', 'Submission_TABLE_grade', 'Professor_TABLE_email', 'Student_TABLE_name', 'Book_TABLE_title', 'Textbook_TABLE_title', 'Book_TABLE_isbn', 'Course_TABLE_title', 'Enrollment_TABLE_grade', 'Library_TABLE_location', 'Book_TABLE_author'}

# %% [markdown]
# 训练

# %%
multi_wrapper.fit()
# multi_wrapper.synthesizer.save("test_model_100k")
# Out:
# 2024-10-16 16:18:23.689 | DEBUG    | sdgx.manager:register:99 - Register for new model: outliertransformer
# 2024-10-16 16:18:23.690 | DEBUG    | sdgx.manager:register:99 - Register for new model: numericvaluetransformer
# 2024-10-16 16:18:23.691 | DEBUG    | sdgx.manager:register:99 - Register for new model: nonvaluetransformer
# 2024-10-16 16:18:23.691 | DEBUG    | sdgx.manager:register:99 - Register for new model: emptytransformer
# 2024-10-16 16:18:23.692 | DEBUG    | sdgx.manager:register:99 - Register for new model: constvaluetransformer
# 2024-10-16 16:18:23.692 | DEBUG    | sdgx.manager:register:99 - Register for new model: columnordertransformer
# 2024-10-16 16:18:23.692 | DEBUG    | sdgx.manager:register:99 - Register for new model: emailgenerator
# 2024-10-16 16:18:23.693 | DEBUG    | sdgx.manager:register:99 - Register for new model: chnpiigenerator
# 2024-10-16 16:18:23.693 | DEBUG    | sdgx.manager:register:99 - Register for new model: intvalueformatter
# 2024-10-16 16:18:23.694 | DEBUG    | sdgx.manager:register:99 - Register for new model: datetimeformatter
# 2024-10-16 16:18:23.694 | INFO     | sdgx.synthesizer:__init__:106 - Using data processors: ['nonvaluetransformer', 'outliertransformer', 'emailgenerator', 'chnpiigenerator', 'intvalueformatter', 'datetimeformatter', 'constvaluetransformer', 'emptytransformer', 'columnordertransformer']
# 2024-10-16 16:18:23.720 | INFO     | sdgx.synthesizer:fit:296 - Fitting data processors...
# 2024-10-16 16:18:23.967 | INFO     | sdgx.data_processors.transformers.nan:fit:71 - NonValueTransformer Fitted.
# 2024-10-16 16:18:23.968 | INFO     | sdgx.data_processors.transformers.nan:fit:87 - NonValueTransformer get int columns: {'Course_TABLE_credits', 'Schedule_TABLE_room', 'Course_TABLE_department', 'REF_TABLE_professor_id', 'REF_TABLE_course_id', 'REF_TABLE_student_id', 'Submission_TABLE_submission_id', 'Professor_TABLE_department', 'Schedule_TABLE_schedule_id', 'Enrollment_TABLE_enrollment_id', 'Submission_TABLE_assignment_id', 'REF_TABLE_textbook_id', 'REF_TABLE_library_id', 'REF_TABLE_book_id', 'Student_TABLE_major', 'BookLoan_TABLE_loan_id'}.
# 2024-10-16 16:18:23.968 | INFO     | sdgx.data_processors.transformers.nan:fit:96 - NonValueTransformer get float columns: set().
# 2024-10-16 16:18:23.968 | INFO     | sdgx.data_processors.transformers.nan:fit:101 - NonValueTransformer get column list from metadata: ['BookLoan_TABLE_loan_id', 'REF_TABLE_book_id', 'REF_TABLE_student_id', 'BookLoan_TABLE_loan_date', 'BookLoan_TABLE_return_date', 'Book_TABLE_title', 'Book_TABLE_author', 'Book_TABLE_isbn', 'REF_TABLE_library_id', 'Library_TABLE_name', 'Library_TABLE_location', 'Student_TABLE_name', 'Student_TABLE_email', 'Student_TABLE_date_of_birth', 'Student_TABLE_major', 'Enrollment_TABLE_enrollment_id', 'REF_TABLE_course_id', 'Enrollment_TABLE_semester', 'Enrollment_TABLE_grade', 'Submission_TABLE_submission_id', 'Submission_TABLE_assignment_id', 'Submission_TABLE_submission_date', 'Submission_TABLE_grade', 'Course_TABLE_title', 'Course_TABLE_credits', 'Course_TABLE_department', 'REF_TABLE_textbook_id', 'Textbook_TABLE_title', 'Textbook_TABLE_author', 'Textbook_TABLE_isbn', 'Schedule_TABLE_schedule_id', 'REF_TABLE_professor_id', 'Schedule_TABLE_room', 'Schedule_TABLE_time_slot', 'Professor_TABLE_name', 'Professor_TABLE_email', 'Professor_TABLE_department'].
# 2024-10-16 16:18:23.969 | INFO     | sdgx.data_processors.transformers.outlier:fit:70 - OutlierTransformer Fitted.
# 2024-10-16 16:18:23.970 | INFO     | sdgx.data_processors.formatters.int:fit:40 - IntValueFormatter Fitted.
# 2024-10-16 16:18:23.971 | WARNING  | sdgx.data_processors.formatters.datetime:fit:70 - Column Schedule_TABLE_time_slot has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-10-16 16:18:23.971 | WARNING  | sdgx.data_processors.formatters.datetime:fit:70 - Column Submission_TABLE_submission_date has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-10-16 16:18:23.971 | INFO     | sdgx.data_processors.formatters.datetime:fit:77 - DatetimeFormatter Fitted.
# 2024-10-16 16:18:23.972 | INFO     | sdgx.data_processors.transformers.const:fit:49 - ConstValueTransformer Fitted.
# 2024-10-16 16:18:23.972 | INFO     | sdgx.data_processors.transformers.empty:fit:54 - EmptyTransformer Fitted.
# 2024-10-16 16:18:23.973 | INFO     | sdgx.data_processors.transformers.column_order:fit:41 - ColumnOrderTransformer Fitted.
# 2024-10-16 16:18:23.973 | INFO     | sdgx.synthesizer:fit:305 - Fitted 9 data processors in  0.005996227264404297s.
# 2024-10-16 16:18:23.973 | INFO     | sdgx.synthesizer:fit:315 - Initializing processed data loader...
# 2024-10-16 16:18:23.999 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-10-16 16:18:24.009 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-10-16 16:18:24.010 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-10-16 16:18:24.044 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-10-16 16:18:24.052 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-10-16 16:18:24.054 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Schedule_TABLE_time_slot was removed because lack of format info.
# 2024-10-16 16:18:24.058 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Submission_TABLE_submission_date was removed because lack of format info.
# 2024-10-16 16:18:24.058 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# 2024-10-16 16:18:24.201 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-10-16 16:18:24.204 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-10-16 16:18:24.205 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-10-16 16:18:24.206 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-10-16 16:18:24.206 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-10-16 16:18:24.207 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-10-16 16:18:24.207 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-10-16 16:18:24.256 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-10-16 16:18:24.266 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-10-16 16:18:24.266 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-10-16 16:18:24.300 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-10-16 16:18:24.308 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-10-16 16:18:24.311 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Schedule_TABLE_time_slot was removed because lack of format info.
# 2024-10-16 16:18:24.314 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Submission_TABLE_submission_date was removed because lack of format info.
# 2024-10-16 16:18:24.314 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# 2024-10-16 16:18:24.459 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-10-16 16:18:24.462 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-10-16 16:18:24.462 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-10-16 16:18:24.463 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-10-16 16:18:24.464 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-10-16 16:18:24.464 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-10-16 16:18:24.465 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-10-16 16:18:24.495 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-10-16 16:18:24.500 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-10-16 16:18:24.501 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-10-16 16:18:24.505 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-10-16 16:18:24.508 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-10-16 16:18:24.508 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Schedule_TABLE_time_slot was removed because lack of format info.
# 2024-10-16 16:18:24.509 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Submission_TABLE_submission_date was removed because lack of format info.
# 2024-10-16 16:18:24.509 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# 2024-10-16 16:18:24.520 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-10-16 16:18:24.522 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-10-16 16:18:24.522 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-10-16 16:18:24.522 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-10-16 16:18:24.523 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-10-16 16:18:24.525 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-10-16 16:18:24.526 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-10-16 16:18:24.541 | INFO     | sdgx.synthesizer:fit:322 - Initialized processed data loader in 0.5659298896789551s
# 2024-10-16 16:18:24.541 | INFO     | sdgx.synthesizer:fit:324 - Model fit Started...
# 2024-10-16 16:18:24.556 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-10-16 16:18:24.566 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-10-16 16:18:24.567 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-10-16 16:18:24.600 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-10-16 16:18:24.609 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-10-16 16:18:24.611 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Schedule_TABLE_time_slot was removed because lack of format info.
# 2024-10-16 16:18:24.614 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Submission_TABLE_submission_date was removed because lack of format info.
# 2024-10-16 16:18:24.614 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# 2024-10-16 16:18:24.762 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-10-16 16:18:24.766 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-10-16 16:18:24.766 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-10-16 16:18:24.767 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-10-16 16:18:24.768 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-10-16 16:18:24.768 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-10-16 16:18:24.769 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-10-16 16:18:24.770 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:248 - Fitting model's transformer...
# 2024-10-16 16:18:24.812 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-10-16 16:18:24.823 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-10-16 16:18:24.824 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-10-16 16:18:24.858 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-10-16 16:18:24.866 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-10-16 16:18:24.868 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Schedule_TABLE_time_slot was removed because lack of format info.
# 2024-10-16 16:18:24.871 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Submission_TABLE_submission_date was removed because lack of format info.
# 2024-10-16 16:18:24.871 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# 2024-10-16 16:18:25.017 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-10-16 16:18:25.020 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-10-16 16:18:25.021 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-10-16 16:18:25.021 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-10-16 16:18:25.022 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-10-16 16:18:25.022 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-10-16 16:18:25.022 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# Preparing data:   0%|          | 0/33 [00:00<?, ?it/s]
# 2024-10-16 16:18:25.030 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column BookLoan_TABLE_loan_id...
# 2024-10-16 16:18:26.303 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column REF_TABLE_book_id...
# 2024-10-16 16:18:27.386 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column REF_TABLE_student_id...
# 2024-10-16 16:18:28.530 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column BookLoan_TABLE_loan_date...
# 2024-10-16 16:18:29.636 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column BookLoan_TABLE_return_date...
# 2024-10-16 16:18:30.744 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Book_TABLE_title...
# 2024-10-16 16:18:30.779 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Book_TABLE_author...
# 2024-10-16 16:18:30.815 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Book_TABLE_isbn...
# 2024-10-16 16:18:30.849 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column REF_TABLE_library_id...
# 2024-10-16 16:18:32.028 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Library_TABLE_name...
# 2024-10-16 16:18:32.062 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Library_TABLE_location...
# 2024-10-16 16:18:32.103 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Student_TABLE_name...
# 2024-10-16 16:18:32.136 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Student_TABLE_date_of_birth...
# 2024-10-16 16:18:33.280 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Student_TABLE_major...
# 2024-10-16 16:18:34.541 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Enrollment_TABLE_enrollment_id...
# 2024-10-16 16:18:35.672 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column REF_TABLE_course_id...
# 2024-10-16 16:18:36.819 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Enrollment_TABLE_semester...
# 2024-10-16 16:18:36.848 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Enrollment_TABLE_grade...
# 2024-10-16 16:18:36.875 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Submission_TABLE_submission_id...
# 2024-10-16 16:18:38.042 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Submission_TABLE_assignment_id...
# 2024-10-16 16:18:39.184 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Submission_TABLE_grade...
# 2024-10-16 16:18:39.213 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Course_TABLE_title...
# 2024-10-16 16:18:39.246 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Course_TABLE_credits...
# 2024-10-16 16:18:39.384 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Course_TABLE_department...
# 2024-10-16 16:18:40.517 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column REF_TABLE_textbook_id...
# 2024-10-16 16:18:41.658 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Textbook_TABLE_title...
# 2024-10-16 16:18:41.692 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Textbook_TABLE_author...
# 2024-10-16 16:18:41.727 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Textbook_TABLE_isbn...
# 2024-10-16 16:18:41.762 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Schedule_TABLE_schedule_id...
# 2024-10-16 16:18:42.865 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column REF_TABLE_professor_id...
# 2024-10-16 16:18:43.945 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Schedule_TABLE_room...
# 2024-10-16 16:18:45.120 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:127 - Fitting discrete column Professor_TABLE_name...
# 2024-10-16 16:18:45.152 | DEBUG    | sdgx.models.components.optimize.sdv_ctgan.data_transformer:fit:132 - Fitting continuous column Professor_TABLE_department...
# 2024-10-16 16:18:46.278 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:250 - Transforming data...
# 2024-10-16 16:18:46.317 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-10-16 16:18:46.327 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-10-16 16:18:46.328 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-10-16 16:18:46.363 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-10-16 16:18:46.371 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-10-16 16:18:46.374 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Schedule_TABLE_time_slot was removed because lack of format info.
# 2024-10-16 16:18:46.377 | WARNING  | sdgx.data_processors.formatters.datetime:convert:97 - Column Submission_TABLE_submission_date was removed because lack of format info.
# 2024-10-16 16:18:46.377 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# 2024-10-16 16:18:46.526 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-10-16 16:18:46.529 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-10-16 16:18:46.530 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-10-16 16:18:46.530 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-10-16 16:18:46.531 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-10-16 16:18:46.532 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-10-16 16:18:46.532 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# Transforming data:   0%|          | 0/33 [00:00<?, ?it/s]
# 2024-10-16 16:18:54.574 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:253 - Sampling data.
# 2024-10-16 16:18:54.593 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:258 - Initialize Generator.
# 2024-10-16 16:18:54.595 | INFO     | sdgx.models.ml.single_table.ctgan:fit:223 - CTGAN prefit finished, start CTGAN training.
# 2024-10-16 16:18:54.597 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:276 - Fit using data_size:20765, data_dim: 246.
# [ColumnTransformInfo(column_name='BookLoan_TABLE_loan_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='REF_TABLE_book_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='REF_TABLE_student_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='BookLoan_TABLE_loan_date', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='BookLoan_TABLE_return_date', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Book_TABLE_title', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Book_TABLE_author', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Book_TABLE_isbn', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='REF_TABLE_library_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Library_TABLE_name', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Library_TABLE_location', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Student_TABLE_name', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Student_TABLE_date_of_birth', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Student_TABLE_major', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Enrollment_TABLE_enrollment_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='REF_TABLE_course_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Enrollment_TABLE_semester', column_type='discrete', transform=OneHotEncoder(), output_info=[SpanInfo(dim=2 ...
# 2024-10-16 16:18:55.138 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:302 - Starting model training, epochs: 1
# Fitting batches:   0%|          | 0/41 [00:00<?, ?it/s]
# 2024-10-16 16:18:59.070 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:383 - Epoch 1, Loss G:  1.8121, Loss D:  0.0556, Time:  3.9309
# 2024-10-16 16:18:59.072 | INFO     | sdgx.models.ml.single_table.ctgan:fit:225 - CTGAN training finished.
# 2024-10-16 16:18:59.072 | INFO     | sdgx.synthesizer:fit:333 - Model fit... Finished

# %%
synthetic_ctgan_data : DataFrame = multi_wrapper.sample(1000, save=False)
# Out:
# 2024-10-16 16:18:59.085 | INFO     | sdgx.synthesizer:sample:357 - Sampling...
# Sampling:   0%|          | 0/1000 [00:00<?, ?it/s]
# Sampling batches:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Inverse transforming:   0%|          | 0/33 [00:00<?, ?it/s]
# 2024-10-16 16:19:03.928 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:155 - Data reverse-converted by NonValueTransformer.
# 2024-10-16 16:19:03.931 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:120 - Data reverse-converted by OutlierTransformer (No Action).
# 2024-10-16 16:19:04.328 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:64 - Data reverse-converted by IntValueFormatter.
# 2024-10-16 16:19:04.329 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:165 - Data reverse-converting by DatetimeFormatter...
# 2024-10-16 16:19:04.330 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:167 - parameters : ['BookLoan_TABLE_return_date', 'BookLoan_TABLE_loan_date', 'Student_TABLE_date_of_birth'], {'BookLoan_TABLE_return_date': '%Y-%m-%d', 'BookLoan_TABLE_loan_date': '%Y-%m-%d', 'Student_TABLE_date_of_birth': '%Y-%m-%d', ('Submission', 'submission_date'): '%Y-%m-%d %H:%M:%S', ('Schedule', 'time_slot'): '%H:%M:%S'}
# 2024-10-16 16:19:04.340 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:173 - Data reverse-converted by DatetimeFormatter... Finished.
# 2024-10-16 16:19:04.341 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:103 - Data reverse-converted by ConstValueTransformer.
# 2024-10-16 16:19:04.341 | INFO     | sdgx.data_processors.transformers.empty:reverse_convert:98 - Data reverse-converted by EmptyTransformer.
# 2024-10-16 16:19:04.343 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:62 - Data reverse-converted by ColumnOrderTransformer.

# %%
import pickle
from mycode.test_20_tables import fetch_data_from_sqlite_filterx
metadatasdv, _ = fetch_data_from_sqlite_filterx(x_args,path=db_path) 
with open('test_data.pickle', 'wb') as f:
    pickle.dump(
        metadatasdv.to_dict()
    , f)

# %%
# from mycode.test_20_tables import fetch_data_from_sqlite_filterx
# from mycode.sdv.evaluation import evaluate
# real_ctgan_data = multi_wrapper.origin_tables
# 
# ret = evaluate(synthetic_ctgan_data, real_ctgan_data,metadatasdv, aggregate=False)
# print(ret.normalized_score.mean())
# ret
# Out:
# nan
#          metric                                     name raw_score  \
# 0  KSComplement  Inverted Kolmogorov-Smirnov D statistic      None
# 1        CSTest                              Chi-Squared      None
#
#   normalized_score  min_value  max_value      goal  \
# 0             None        0.0        1.0  MAXIMIZE
# 1             None        0.0        1.0  MAXIMIZE
#
#                                                error
# 0  Encountered the following errors: {'BookLoan':...
# 1  Encountered the following errors: {'BookLoan':...

# %%
metadatasdv.get_tables()
# Out:
# ['BookLoan',
#  'Book',
#  'Library',
#  'Student',
#  'Enrollment',
#  'Submission',
#  'Course',
#  'CourseTextbook',
#  'Textbook',
#  'Schedule',
#  'Professor']

# %%
real_ctgan_data
# Out:
# {'BookLoan':       loan_id  book_id  student_id   loan_date return_date
#  0           1        1        5068  2024-07-19  2025-07-30
#  1           2        2        3802  2024-08-25  2024-12-12
#  2           3        3        7175  2024-03-04  2025-02-09
#  3           4        4        9206  2024-08-17  2025-01-27
#  4           5        5        6392  2024-06-03  2025-06-10
#  ...       ...      ...         ...         ...         ...
#  9995     9996     9996        8228  2024-05-14  2025-03-30
#  9996     9997     9997        6451  2024-04-10  2025-04-01
#  9997     9998     9998        3486  2024-01-14  2024-12-09
#  9998     9999     9999        2281  2023-12-28  2025-08-23
#  9999    10000    10000         801  2024-03-03  2025-07-24
#
#  [10000 rows x 5 columns],
#  'Book':       book_id                     title            author               isbn  \
#  0           1               Model bank.       Ricky Brown  978-1-4017-1762-9
#  1           2        Player vote local.  Charles Williams  978-0-04-723109-4
#  2           3  Fight treatment success.       David Welch  978-1-4982-0862-8
#  3           4  Majority miss candidate.   Kenneth Maynard  978-0-519-17026-5
#  4           5            None them hit.      Taylor Adams  978-1-03-920737-0
#  ...       ...                       ...               ...                ...
#  9995     9996           Which American.      James Farmer  978-1-4984-3530-7
#  9996     9997        Present both side.      Carrie Kelly  978-1-67129-381-6
#  9997     9998   Listen interview world.     Richard Floyd  978-0-7738-9332-0
#  9998     9999    Challenge last suffer.    Robert Holland  978-1-67998-842-4
#  9999    10000       Water clearly kind.     Mason Herrera  978-1-359-78435-3
#
#        library_id
#  0              1
#  1              2
#  2              3
#  3              4
#  4              5
#  ...          ...
#  9995        9996
#  9996        9997
#  9997        9998
#  9998        9999
#  9999       10000
#
#  [10000 rows x 5 columns],
#  'Library':       library_id                                   name  \
#  0              1                   Wilson Group Library
#  1              2       Spencer, Heath and Young Library
#  2              3  Gutierrez, Ellis and Peterson Library
#  3              4      Huffman, Byrd and Burnett Library
#  4              5                  Ward and Sons Library
#  ...          ...                                    ...
#  9995        9996                  Rodriguez PLC Library
#  9996        9997                  Stewart Group Library
#  9997        9998                   Johnston Inc Library
#  9998        9999                 Williams-Smith Library
#  9999       10000               Glenn-Mclaughlin Library
#
#                                                 location
#  0     936 Herrera Trafficway\nNew Samanthaside, AS 8...
#  1                      PSC 2343, Box 7300\nAPO AA 07314
#  2                      PSC 5691, Box 7628\nAPO AA 44060
#  3              21149 Clarke Vista\nNorth John, MD 02236
#  4         5769 Rachel Island\nWest Aaronburgh, MS 73845
#  ...                                                 ...
#  9995  70616 David Square Suite 430\nNew Williamside,...
#  9996                      USNV Cunningham\nFPO AP 71205
#  9997         051 Huber Trafficway\nNew Andrew, KY 07874
#  9998  46747 Stevenson Corners\nWest Kimberlyland, WY...
#  9999                757 Baker Parks\nClayview, MH 32077
#
#  [10000 rows x 3 columns],
#  'Student':       student_id             name                        email date_of_birth  \
#  0              1     Joshua Smith         twatkins@example.com    2001-12-28
#  1              2      Aaron Rocha     sanchezlaura@example.org    2005-06-30
#  2              3       James Ball            gross@example.org    2001-05-03
#  3              4    Nathan Zamora         mwatkins@example.com    2002-12-17
#  4              5      Gerald Lamb   johnsonmelissa@example.org    1998-05-01
#  ...          ...              ...                          ...           ...
#  9995        9996  Jennifer Fields          charris@example.org    2001-10-16
#  9996        9997     Alison Clark  michaelfigueroa@example.org    1998-01-11
#  9997        9998    Matthew Brown             glee@example.com    1996-10-11
#  9998        9999    Sandra Turner         robert45@example.net    2004-01-23
#  9999       10000   Thomas Russell         nicole16@example.net    2004-11-06
#
#       major
#  0     8900
#  1     6911
#  2      414
#  3     7938
#  4     7910
#  ...    ...
#  9995  8561
#  9996  9291
#  9997  8365
#  9998  3540
#  9999  4754
#
#  [10000 rows x 5 columns],
#  'Enrollment':       enrollment_id  student_id  course_id     semester grade
#  0                 1        4869       5544  Winter 2023     D
#  1                 2        3804       2637    Fall 2021     F
#  2                 3        7290       7430    Fall 2022     A
#  3                 4        2455        656  Spring 2021     A
#  4                 5        9410       2469  Winter 2023     D
#  ...             ...         ...        ...          ...   ...
#  9995           9996        1008       5247  Summer 2020     A
#  9996           9997        5848       7036  Spring 2023     A
#  9997           9998        2265       4512  Winter 2023     D
#  9998           9999        9246        596    Fall 2021  None
#  9999          10000        5355       8502  Summer 2019     F
#
#  [10000 rows x 5 columns],
#  'Submission':        submission_id  assignment_id  student_id      submission_date grade
#  0                  1           3434         522  2022-08-25 04:14:14     I
#  1                  2           1814        8535  2022-01-01 12:39:41     A
#  2                  3           2573        4700  2022-10-10 15:18:32     F
#  3                  4            998        2464  2022-03-10 16:12:42     A
#  4                  5           2599        8773  2022-01-19 15:49:39     C
#  ...              ...            ...         ...                  ...   ...
#  11076          11077           9114        9044  2022-06-18 08:38:42     D
#  11077          11078           9207        6899  2022-02-06 05:29:29     I
#  11078          11079           2293        3583  2022-06-04 17:43:01     B
#  11079          11080           3663        1654  2022-07-30 05:50:04     F
#  11080          11081           2732        9224  2022-01-28 10:13:30     F
#
#  [11081 rows x 5 columns],
#  'Course':       course_id                       title  credits department
#  0             1                     Art TV.        3       9889
#  1             2               Let one more.        4       8367
#  2             3           Dog late herself.        4       8913
#  3             4               Either local.        2       7846
#  4             5                  Occur pay.        4       1682
#  ...         ...                         ...      ...        ...
#  9995       9996              Figure speech.        2       8289
#  9996       9997           Each manage good.        1       1579
#  9997       9998       Through only clearly.        1       9323
#  9998       9999  Congress scientist factor.        3       2316
#  9999      10000   Fine discover view worry.        1       7307
#
#  [10000 rows x 4 columns],
#  'CourseTextbook':       course_id  textbook_id
#  0          8067            1
#  1          4579            2
#  2          9750            3
#  3          8299            4
#  4          7226            5
#  ...         ...          ...
#  9995       9813         9996
#  9996       7525         9997
#  9997       7552         9998
#  9998       9541         9999
#  9999       2615        10000
#
#  [10000 rows x 2 columns],
#  'Textbook':       textbook_id                   title             author  \
#  0               1                   True.   Donna Miller DDS
#  1               2               Be begin.    Caroline Campos
#  2               3          Resource like.        Ryan Orozco
#  3               4             Price home.  Sarah Fitzpatrick
#  4               5            Create test.    Heather Marquez
#  ...           ...                     ...                ...
#  9995         9996         Important walk.         Hannah Kim
#  9996         9997      Any within finish.       Kyle Garrett
#  9997         9998    Place agency father.       Krista Welch
#  9998         9999  Experience grow would.       Andrea Evans
#  9999        10000         Wife interview.       Joyce Bowman
#
#                     isbn
#  0     978-1-85413-961-0
#  1     978-1-4286-7328-1
#  2     978-0-515-73347-1
#  3     978-1-870864-38-1
#  4     978-0-360-03944-5
#  ...                 ...
#  9995  978-0-88320-684-3
#  9996  978-1-60719-122-3
#  9997  978-1-02-420975-4
#  9998  978-0-8324-2672-8
#  9999  978-1-278-83403-0
#
#  [10000 rows x 4 columns],
#  'Schedule':       schedule_id  course_id  professor_id   room time_slot
#  0               1       8067          1608    531  15:54:02
#  1               2       4579          6849  10839  22:46:56
#  2               3       9750           677   1494  05:27:52
#  3               4       8299          1639  14555  01:18:20
#  4               5       7226          7600    802  04:49:47
#  ...           ...        ...           ...    ...       ...
#  9995         9996       9813          2739   0640  13:19:21
#  9996         9997       7525          5986  65520  10:38:31
#  9997         9998       7552          9510  06954  17:49:18
#  9998         9999       9541          3107   8695  06:24:17
#  9999        10000       2615          9619    919  18:20:27
#
#  [10000 rows x 5 columns],
#  'Professor':       professor_id            name                        email department
#  0                1  William Fields          brett64@example.com       1491
#  1                2    Sean Maxwell  stanleymckenzie@example.com       7929
#  2                3   John Mitchell           mary02@example.com       4704
#  3                4        Ray Dunn           jjones@example.org       3745
#  4                5   Jeremy Butler     mariajackson@example.com       5326
#  ...            ...             ...                          ...        ...
#  9995          9996  Michael Wright         bjohnson@example.net       6400
#  9996          9997     Lisa Morgan     howellrobert@example.org       7158
#  9997          9998   Amanda Barnes       dcontreras@example.net       5389
#  9998          9999     Frank Jones     sanderslarry@example.org       5530
#  9999         10000    Joseph Johns          nwagner@example.net       3984
#
#  [10000 rows x 4 columns]}

# %%
synthetic_ctgan_data
# Out:
# {'BookLoan':     return_date   loan_date  loan_id  student_id  book_id
#  0    2025-05-26  2024-01-28     7316        2613     2958
#  1    2024-12-08  2024-08-23     3841        2085      789
#  2    2025-05-15  2024-05-02     6190        2709     5005
#  3    2025-07-02  2024-07-13     4695        8762     5581
#  4    2024-12-11  2024-04-19     8434         966     1445
#  ..          ...         ...      ...         ...      ...
#  995  2024-11-12  2024-09-11     5590        7964     1536
#  996  2024-10-09  2024-08-05     3360        9883     4374
#  997  2024-09-16  2024-07-03     1150        8075     6330
#  998  2025-06-09  2023-12-15     5646        2377     1011
#  999  2025-04-17  2023-09-18     5301        8431      572
#
#  [1000 rows x 5 columns],
#  'Book':                   isbn                  title            author  library_id  \
#  0    978-0-665-47728-7       Mouth close any.       David Brown        2707
#  1    978-0-7116-9094-3  Sea necessary within.       Mary Cannon        5197
#  2    978-0-645-52792-6                 Smile.     Joseph Graham        8892
#  3    978-1-167-87113-9   Possible party onto.      Joshua Owens        4586
#  4    978-0-304-39077-9           Environment.       Ryan Willis        4441
#  ..                 ...                    ...               ...         ...
#  995  978-0-518-75984-3             Our might.  Jennifer Wheeler        8029
#  996  978-0-7439-8541-3           One between.   Natasha Shepard        3002
#  997  978-1-06-347949-1  National from policy.      Michael Ward        4228
#  998  978-0-09-179896-3   Responsibility hand.        Ivan Scott        1347
#  999  978-0-513-44248-1        Rule knowledge.      Debbie Ortiz        1251
#
#       book_id
#  0       2958
#  1        789
#  2       5005
#  3       5581
#  4       1445
#  ..       ...
#  995     1536
#  996     4374
#  997     6330
#  998     1011
#  999      572
#
#  [1000 rows x 5 columns],
#  'Library':                                       name  \
#  0      Morales, Hodge and Mitchell Library
#  1                        Gomez Inc Library
#  2                    Peck and Sons Library
#  3    Gregory, Gillespie and Thomas Library
#  4                      Zuniga-Cole Library
#  ..                                     ...
#  995                    Zuniga-Cole Library
#  996                    Mcgrath Inc Library
#  997                  Manning Group Library
#  998                    Hickman Ltd Library
#  999                      Ray-Burns Library
#
#                                                location  library_id
#  0        56730 Donna Forge\nRodriguezborough, MD 85138        2707
#  1     774 Lamb Villages\nEast Stephanieville, NJ 30415        5197
#  2     192 Rowe Fall Apt. 672\nPort Tanyaport, NH 45008        8892
#  3    19237 Gallagher Street Suite 517\nNorth Adrian...        4586
#  4          41714 Douglas Valley\nWest Autumn, DC 06221        4441
#  ..                                                 ...         ...
#  995  10976 Natasha Ford Apt. 592\nDanielmouth, IN 1...        8029
#  996  5352 Armstrong Valleys Apt. 628\nDanielland, T...        3002
#  997      4744 Jacqueline Island\nEast Andrew, WY 23065        4228
#  998  24926 Harding Plaza Apt. 904\nWest Brandimouth...        1347
#  999              334 Cameron Dale\nPort Anna, WA 68735        1251
#
#  [1000 rows x 3 columns],
#  'Student':     date_of_birth                           email  major              name  \
#  0      2004-12-26     jonathanpineda@anderson.biz   5491      Taylor Green
#  1      2003-03-07        stacy65@giles-briggs.com   8747        Maria Meza
#  2      2004-10-06          watsonnicole@watts.com   3192         Tara Wood
#  3      2006-03-20               roger19@drake.com   5497      Kaitlyn Webb
#  4      2006-10-20    johnsonamy@burnett-ellis.com   8433     Karen Mora MD
#  ..            ...                             ...    ...               ...
#  995    1996-06-06             sarah69@johnson.com   8250         Donna Kim
#  996    1998-07-22              gloria59@patel.com   7350      Lauren Jones
#  997    1997-08-20             mayerdavid@lamb.com   1527     Karina Fisher
#  998    1996-11-20       jordanalvarez@spencer.net   2937       Kayla Ramos
#  999    2000-08-29  daniel00@gonzalez-humphrey.com   2591  Christopher Hart
#
#       student_id
#  0          2613
#  1          2085
#  2          2709
#  3          8762
#  4           966
#  ..          ...
#  995        7964
#  996        9883
#  997        8075
#  998        2377
#  999        8431
#
#  [1000 rows x 5 columns],
#  'Enrollment':         semester grade  enrollment_id  student_id  course_id
#  0    Winter 2022     A           5931        2613       2111
#  1    Summer 2021     A           4208        2085       3674
#  2    Summer 2022     C           9758        2709       7073
#  3    Winter 2021                 6487        8762      10275
#  4    Summer 2019     B           9681         966       5116
#  ..           ...   ...            ...         ...        ...
#  995  Spring 2020     A           9681        7964       2207
#  996    Fall 2020     B           7491        9883      10165
#  997  Summer 2022     D           6377        8075       5245
#  998  Summer 2023                 6699        2377       3934
#  999  Winter 2023     C           6441        8431       2318
#
#  [1000 rows x 5 columns],
#  'Submission':      submission_date  submission_id  assignment_id grade  student_id
#  0                NaN           8580           4388     C        2613
#  1                NaN           1542           1759     A        2085
#  2                NaN           3262           1062     A        2709
#  3                NaN           5347           1594     A        8762
#  4                NaN           5798           3683     A         966
#  ..               ...            ...            ...   ...         ...
#  995              NaN           4416           6001     I        7964
#  996              NaN           3913            801     D        9883
#  997              NaN           5960           5771     C        8075
#  998              NaN           8405           4100     D        2377
#  999              NaN           4557           1725     B        8431
#
#  [1000 rows x 5 columns],
#  'Course':                              title  department  credits  course_id
#  0    Policy mission machine power.        1315        4       2111
#  1               Show safe suggest.        6003        2       3674
#  2                      Work other.        4996        3       7073
#  3               Save guy discover.         483        1      10275
#  4                 Represent small.        6746        4       5116
#  ..                             ...         ...      ...        ...
#  995             Record court city.        1459        3       2207
#  996             Raise tell mother.        7169        1      10165
#  997            National president.        5199        4       5245
#  998        Practice candidate hot.        7967        3       3934
#  999                     Gun group.         901        2       2318
#
#  [1000 rows x 4 columns],
#  'CourseTextbook':      textbook_id  course_id
#  0           4113       2111
#  1           5125       3674
#  2            664       7073
#  3           2340      10275
#  4           5176       5116
#  ..           ...        ...
#  995         3476       2207
#  996         2496      10165
#  997         2044       5245
#  998         2432       3934
#  999         6032       2318
#
#  [1000 rows x 2 columns],
#  'Textbook':                   isbn                               title  \
#  0    978-0-929465-98-2               Sister situation bag.
#  1    978-0-428-77994-8                Investment movement.
#  2    978-0-7222-7197-1                               Land.
#  3    978-0-8432-9305-0                Popular write prove.
#  4    978-0-12-106707-6                       College term.
#  ..                 ...                                 ...
#  995  978-0-908090-21-1                  Himself scientist.
#  996  978-0-8133-8662-1                       Pretty hotel.
#  997  978-1-04-671767-1  Industry science measure practice.
#  998  978-0-9553561-6-2                     Computer these.
#  999  978-1-270-48410-3                     Him beat white.
#
#                   author  textbook_id
#  0            Megan Byrd         4113
#  1          Heidi Larsen         5125
#  2        Jonathan Lopez          664
#  3       Joshua Andersen         2340
#  4           Jesus Small         5176
#  ..                  ...          ...
#  995      Aaron Anderson         3476
#  996  Christopher Morris         2496
#  997    Calvin Gallagher         2044
#  998      Cameron Bright         2432
#  999      Aaron Anderson         6032
#
#  [1000 rows x 4 columns],
#  'Schedule':      room  time_slot  schedule_id  course_id  professor_id
#  0    -499        NaN         6266       2111          1966
#  1    -178        NaN         6662       3674          8282
#  2    -209        NaN         2187       7073          -397
#  3     -14        NaN         9635      10275          1838
#  4    3994        NaN         1267       5116          8983
#  ..    ...        ...          ...        ...           ...
#  995  1394        NaN        10174       2207          6555
#  996   611        NaN         9637      10165          5554
#  997  -599        NaN         2792       5245          4881
#  998  6430        NaN         6035       3934          3600
#  999  -494        NaN         1855       2318          7532
#
#  [1000 rows x 5 columns],
#  'Professor':                           email  department               name  professor_id
#  0           jennifer28@beck.com       10663     Jonathan Mckee          1966
#  1             james11@clark.com        4727    Kevin Schneider          8282
#  2        glen89@warren-lamb.com        5599     Robert Solomon          -397
#  3            fdavid@russell.net        9096    Morgan Williams          1838
#  4      ramirezalyssa@ritter.biz        8188  Kathleen Cantrell          8983
#  ..                          ...         ...                ...           ...
#  995  eileen89@todd-marshall.net        8715      Jennifer Cobb          6555
#  996  jenniferjohnson@medina.com        6656    Joshua Richards          5554
#  997     cookcassandra@smith.com        4893      Douglas Hines          4881
#  998       gonzalezcaleb@day.com        2016      Melinda Stone          3600
#  999       spencer51@montoya.com        5348    Dominic Johnson          7532
#
#  [1000 rows x 4 columns]}
