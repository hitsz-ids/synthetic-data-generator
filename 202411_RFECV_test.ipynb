# %%
from mycode.multi_rfe_ctgan import MultiTableRfecvCTGAN
from mycode import dataset
from mycode.testcode import Xargs

db_path = dataset.DatabaseTest.path_10k
db_level = db_path[db_path.rfind("/") + 1:db_path.rfind(".db")]
table_level = '6'
x_args = Xargs.XArgs.tables_6
from mycode.testcode.Xargs import XMetaBuilder
# exclude_processor=['specificcombinationtransformer', 'fixedcombinationtransformer', 'positivenegativefilter']
model = MultiTableRfecvCTGAN(db_path=db_path, x_args=x_args)
model.init(meta_builder=XMetaBuilder(x_args))
model.to_training
# Out:
# C:\Users\Elvin\Desktop\GitHub\synthetic-data-generator\sdgx\models\components\optimize\sdv_ctgan\data_sampler.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm import autonotebook as tqdm
# 2024-11-22 22:59:14.557 | INFO     | mycode.multi_rfe_ctgan:__init__:64 - Using data processors: ['specificcombinationtransformer', 'fixedcombinationtransformer', 'nonvaluetransformer', 'outliertransformer', 'emailgenerator', 'chnpiigenerator', 'intvalueformatter', 'datetimeformatter', 'constvaluetransformer', 'positivenegativefilter', 'emptytransformer', 'columnordertransformer']
# 2024-11-22 22:59:14.923 | INFO     | sdgx.data_models.metadata:from_dataloader:294 - Inspecting metadata...
# 10000 10000 10000 10000 10159 12338
# 12338 lines x 23 columns
# 2024-11-22 22:59:18.097 | INFO     | sdgx.data_models.metadata:update_primary_key:508 - Primary Key updated: set().
# 2024-11-22 22:59:18.116 | INFO     | sdgx.data_processors.transformers.specific_combination:fit:70 - Fit data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-22 22:59:18.116 | INFO     | sdgx.data_processors.transformers.nan:fit:81 - NonValueTransformer Fitted.
# 2024-11-22 22:59:18.117 | INFO     | sdgx.data_processors.transformers.nan:fit:97 - NonValueTransformer get int columns: {'REF__TABLE_library_id', 'Submission_TABLE_assignment_id', 'REF__TABLE_student_id', 'Enrollment_TABLE_course_id', 'Submission_TABLE_submission_id', 'Enrollment_TABLE_enrollment_id', 'BookLoan_TABLE_loan_id', 'REF__TABLE_book_id'}.
# 2024-11-22 22:59:18.117 | INFO     | sdgx.data_processors.transformers.nan:fit:106 - NonValueTransformer get float columns: set().
# 2024-11-22 22:59:18.118 | INFO     | sdgx.data_processors.transformers.nan:fit:111 - NonValueTransformer get column list from metadata: ['BookLoan_TABLE_loan_id', 'REF__TABLE_book_id', 'REF__TABLE_student_id', 'BookLoan_TABLE_loan_date', 'BookLoan_TABLE_return_date', 'Book_TABLE_title', 'Book_TABLE_author', 'Book_TABLE_isbn', 'REF__TABLE_library_id', 'Library_TABLE_name', 'Library_TABLE_location', 'Student_TABLE_name', 'Student_TABLE_email', 'Student_TABLE_date_of_birth', 'Student_TABLE_major', 'Enrollment_TABLE_enrollment_id', 'Enrollment_TABLE_course_id', 'Enrollment_TABLE_semester', 'Enrollment_TABLE_grade', 'Submission_TABLE_submission_id', 'Submission_TABLE_assignment_id', 'Submission_TABLE_submission_date', 'Submission_TABLE_grade'].
# 2024-11-22 22:59:18.118 | INFO     | sdgx.data_processors.transformers.outlier:fit:76 - OutlierTransformer Fitted.
# 2024-11-22 22:59:18.119 | INFO     | sdgx.data_processors.formatters.int:fit:43 - IntValueFormatter Fitted.
# 2024-11-22 22:59:18.119 | INFO     | sdgx.data_processors.formatters.datetime:fit:83 - DatetimeFormatter Fitted.
# 2024-11-22 22:59:18.120 | INFO     | sdgx.data_processors.transformers.const:fit:53 - ConstValueTransformer Fitted.
# 2024-11-22 22:59:18.120 | INFO     | sdgx.data_processors.filter.positive_negative:fit:58 - PositiveNegativeFilter Fitted.
# 2024-11-22 22:59:18.121 | INFO     | sdgx.data_processors.transformers.empty:fit:57 - EmptyTransformer Fitted.
# 2024-11-22 22:59:18.122 | INFO     | sdgx.data_processors.transformers.column_order:fit:44 - ColumnOrderTransformer Fitted.
# 2024-11-22 22:59:18.122 | INFO     | mycode.multi_rfe_ctgan:_data_preprocess:117 - Fitted 12 data processors in  0.02292346954345703s.
# 2024-11-22 22:59:18.123 | INFO     | mycode.multi_rfe_ctgan:_data_preprocess:130 - Initializing processed data loader...
# 2024-11-22 22:59:18.135 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-22 22:59:18.135 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:167 - Converting data using FixedCombinationTransformer...
# {'datetime': ['Submission_TABLE_submission_date'], 'time': []}
# metadata.int_columns={'REF__TABLE_library_id', 'Submission_TABLE_assignment_id', 'REF__TABLE_student_id', 'Enrollment_TABLE_course_id', 'Submission_TABLE_submission_id', 'Enrollment_TABLE_enrollment_id', 'BookLoan_TABLE_loan_id', 'REF__TABLE_book_id'}
# metadata.float_columns=set()
# metadata.const_columns=set()
# metadata.bool_columns=set()
# metadata.discrete_columns={'Submission_TABLE_grade', 'Student_TABLE_name', 'Book_TABLE_title', 'Library_TABLE_name', 'Book_TABLE_isbn', 'Library_TABLE_location', 'Book_TABLE_author', 'Student_TABLE_major', 'Enrollment_TABLE_semester', 'Enrollment_TABLE_grade', 'Student_TABLE_email'}
# 2024-11-22 22:59:32.232 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:195 - Converting data using FixedCombinationTransformer... Finished.
# 2024-11-22 22:59:32.232 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-11-22 22:59:32.244 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-11-22 22:59:32.244 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-11-22 22:59:32.263 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-11-22 22:59:32.268 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-11-22 22:59:32.269 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter...
# 2024-11-22 22:59:32.487 | INFO     | sdgx.data_processors.formatters.datetime:convert:111 - Converting data using DatetimeFormatter... Finished.
# 2024-11-22 22:59:32.489 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-11-22 22:59:32.490 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-11-22 22:59:32.490 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-11-22 22:59:32.490 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-11-22 22:59:32.491 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-11-22 22:59:32.492 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-11-22 22:59:32.492 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-11-22 22:59:32.536 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-22 22:59:32.537 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:162 - Converting data using FixedCombinationTransformer... Finished (No action).
# 2024-11-22 22:59:32.537 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-11-22 22:59:32.545 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-11-22 22:59:32.545 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-11-22 22:59:32.550 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-11-22 22:59:32.552 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-11-22 22:59:32.552 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter...
# 2024-11-22 22:59:32.604 | INFO     | sdgx.data_processors.formatters.datetime:convert:111 - Converting data using DatetimeFormatter... Finished.
# 2024-11-22 22:59:32.605 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-11-22 22:59:32.606 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-11-22 22:59:32.606 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-11-22 22:59:32.607 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-11-22 22:59:32.607 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-11-22 22:59:32.608 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-11-22 22:59:32.609 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-11-22 22:59:32.626 | INFO     | mycode.multi_rfe_ctgan:_data_preprocess:136 - Initialized processed data loader in 14.503154039382935s
# C:\Users\Elvin\Desktop\GitHub\synthetic-data-generator\mycode\multi_rfe_ctgan.py:96: UserWarning: Detected columns deleting by data processors, we will attach original data to train RFECV.
#   warnings.warn("Detected columns deleting by data processors, we will attach original data to train RFECV.")
# Choosing Cols:   0%|          | 0/22 [00:00<?, ?it/s]
# [<mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x226ffc14c70>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x226ffc15870>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x226ffc16a70>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x226ffc16590>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x226ffc160b0>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x226ffc15030>]

# %%
for i in range(len(model.to_training)):
    tbn = model.to_training[i].table_name
    if model.to_training[i].tables is None:
        print(tbn)
        continue
    print(tbn, len(model.multi_x_join.origin_tables[tbn].columns),
          len(model.to_training[i].tables.columns),
          {
              k: len(v) for k, v in model.to_training[i].target_column_name_selected_map.items()
          }, model.to_training[i].tables.columns)
# Out:
# BookLoan 5 21 {'BookLoan_TABLE_return_date': 20} Index(['REF__TABLE_library_id', 'Submission_TABLE_assignment_id',
#        'Student_TABLE_name', 'REF__TABLE_student_id',
#        'Enrollment_TABLE_course_id', 'Book_TABLE_isbn', 'Book_TABLE_author',
#        'Enrollment_TABLE_semester', 'Enrollment_TABLE_grade',
#        'Student_TABLE_major', 'BookLoan_TABLE_loan_id', 'Book_TABLE_title',
#        'Library_TABLE_name', 'Library_TABLE_location',
#        'Submission_TABLE_submission_id', 'BookLoan_TABLE_return_date',
#        'Enrollment_TABLE_enrollment_id', 'Submission_TABLE_submission_date',
#        'Student_TABLE_date_of_birth', 'BookLoan_TABLE_loan_date',
#        'REF__TABLE_book_id'],
#       dtype='object')
# Book
# Library
# Student 5 4 {} Index(['Student_TABLE_date_of_birth', 'Student_TABLE_name',
#        'REF__TABLE_student_id', 'Student_TABLE_major'],
#       dtype='object')
# Enrollment
# Submission 5 5 {'Submission_TABLE_grade': 4} Index(['Submission_TABLE_assignment_id', 'Submission_TABLE_grade',
#        'Submission_TABLE_submission_date', 'REF__TABLE_student_id',
#        'Submission_TABLE_submission_id'],
#       dtype='object')

# %%
model.fit()
# Out:
# 2024-11-22 22:59:53.032 | INFO     | mycode.multi_rfe_ctgan:_fit_argument_table_ctgan:344 - Fitting RFE-CTGAN model on table BookLoan...
# 2024-11-22 22:59:53.087 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:249 - Fitting model's transformer...
# Preparing data:  52%|#####2    | 11/21 [00:03<00:02,  3.36it/s]
# 2024-11-22 23:00:00.606 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:251 - Transforming data...
# Transforming data:   5%|4         | 1/21 [00:04<01:34,  4.72s/it]
# 2024-11-22 23:00:06.524 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:254 - Sampling data.
# 2024-11-22 23:00:06.536 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:259 - Initialize Generator.
# 2024-11-22 23:00:06.538 | INFO     | sdgx.models.ml.single_table.ctgan:fit:224 - CTGAN prefit finished, start CTGAN training.
# 2024-11-22 23:00:06.539 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:276 - Fit using data_size:12338, data_dim: 165.
# 2024-11-22 23:00:07.106 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:302 - Starting model training, epochs: 1
# 2024-11-22 23:00:08.787 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:382 - Epoch 1, Loss G:  2.3207, Loss D:  0.1161, Time:  1.6801
# 2024-11-22 23:00:08.788 | INFO     | sdgx.models.ml.single_table.ctgan:fit:226 - CTGAN training finished.
# 2024-11-22 23:00:08.789 | INFO     | mycode.multi_rfe_ctgan:_fit_argument_table_ctgan:344 - Fitting RFE-CTGAN model on table Student...
# 2024-11-22 23:00:08.818 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:249 - Fitting model's transformer...
# data_dim: 165, time: 15.76s
# 2024-11-22 23:00:10.082 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:251 - Transforming data...
# 2024-11-22 23:00:12.096 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:254 - Sampling data.
# 2024-11-22 23:00:12.097 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:259 - Initialize Generator.
# 2024-11-22 23:00:12.100 | INFO     | sdgx.models.ml.single_table.ctgan:fit:224 - CTGAN prefit finished, start CTGAN training.
# 2024-11-22 23:00:12.100 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:276 - Fit using data_size:12338, data_dim: 24.
# 2024-11-22 23:00:12.101 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:302 - Starting model training, epochs: 1
# 2024-11-22 23:00:12.645 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:382 - Epoch 1, Loss G:  0.0434, Loss D:  0.0410, Time:  0.5428
# 2024-11-22 23:00:12.646 | INFO     | sdgx.models.ml.single_table.ctgan:fit:226 - CTGAN training finished.
# 2024-11-22 23:00:12.647 | INFO     | mycode.multi_rfe_ctgan:_fit_argument_table_ctgan:344 - Fitting RFE-CTGAN model on table Submission...
# 2024-11-22 23:00:12.663 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:249 - Fitting model's transformer...
# data_dim: 24, time: 3.86s
# 2024-11-22 23:00:15.101 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:251 - Transforming data...
# 2024-11-22 23:00:17.323 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:254 - Sampling data.
# 2024-11-22 23:00:17.327 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:259 - Initialize Generator.
# 2024-11-22 23:00:17.329 | INFO     | sdgx.models.ml.single_table.ctgan:fit:224 - CTGAN prefit finished, start CTGAN training.
# 2024-11-22 23:00:17.329 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:276 - Fit using data_size:12338, data_dim: 50.
# 2024-11-22 23:00:17.331 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:302 - Starting model training, epochs: 1
# 2024-11-22 23:00:18.148 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:382 - Epoch 1, Loss G:  1.4230, Loss D:  0.2111, Time:  0.8175
# 2024-11-22 23:00:18.151 | INFO     | sdgx.models.ml.single_table.ctgan:fit:226 - CTGAN training finished.
# data_dim: 50, time: 5.5s

# %%
data = model.sample(1000)
# Out:
# Sampling:   0%|          | 0/1000 [00:00<?, ?it/s]
# CTGAN Generated 1500 raw samples
# 2024-11-22 23:00:23.740 | INFO     | sdgx.data_processors.transformers.specific_combination:reverse_convert:117 - Reverse converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-22 23:00:23.741 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:230 - Reverse converting data using FixedCombinationTransformer...
# Recovered 1500 samples
# 2024-11-22 23:00:29.021 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:254 - Reverse converting data using FixedCombinationTransformer... Finished.
# 2024-11-22 23:00:29.022 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:165 - Data reverse-converted by NonValueTransformer.
# 2024-11-22 23:00:29.024 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:126 - Data reverse-converted by OutlierTransformer (No Action).
# 2024-11-22 23:00:29.282 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:69 - Data reverse-converted by IntValueFormatter.
# 2024-11-22 23:00:29.283 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:164 - Data reverse-converting by DatetimeFormatter...
# 2024-11-22 23:00:29.283 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:166 - parameters : ['Student_TABLE_date_of_birth', 'Submission_TABLE_submission_date', 'BookLoan_TABLE_return_date', 'BookLoan_TABLE_loan_date'], {'Student_TABLE_date_of_birth': '%Y-%m-%d', 'BookLoan_TABLE_return_date': '%Y-%m-%d', 'BookLoan_TABLE_loan_date': '%Y-%m-%d', 'Submission_TABLE_submission_date': '%Y-%m-%d %H:%M:%S'}
# 2024-11-22 23:00:29.299 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:172 - Data reverse-converted by DatetimeFormatter... Finished.
# 2024-11-22 23:00:29.300 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:107 - Data reverse-converted by ConstValueTransformer.
# 2024-11-22 23:00:29.301 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:86 - Data reverse-converted by PositiveNegativeFilter Start with Shape: (1500, 22).
# 2024-11-22 23:00:29.303 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:106 - Data reverse-converted by PositiveNegativeFilter with Output Shape: (1500, 22).
# 2024-11-22 23:00:29.304 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:65 - Data reverse-converted by ColumnOrderTransformer.
# Sampling:   0%|          | 0/1000 [00:00<?, ?it/s]
# CTGAN Generated 1500 raw samples
# 2024-11-22 23:00:29.904 | INFO     | sdgx.data_processors.transformers.specific_combination:reverse_convert:117 - Reverse converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-22 23:00:29.905 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:230 - Reverse converting data using FixedCombinationTransformer...
# 2024-11-22 23:00:29.906 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:254 - Reverse converting data using FixedCombinationTransformer... Finished.
# 2024-11-22 23:00:29.907 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:165 - Data reverse-converted by NonValueTransformer.
# 2024-11-22 23:00:29.907 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:126 - Data reverse-converted by OutlierTransformer (No Action).
# Recovered 1500 samples
# 2024-11-22 23:00:30.162 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column REF__TABLE_library_id not found in processed_data.
# 2024-11-22 23:00:30.163 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column Submission_TABLE_assignment_id not found in processed_data.
# 2024-11-22 23:00:30.164 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column Enrollment_TABLE_course_id not found in processed_data.
# 2024-11-22 23:00:30.164 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column Submission_TABLE_submission_id not found in processed_data.
# 2024-11-22 23:00:30.165 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column Enrollment_TABLE_enrollment_id not found in processed_data.
# 2024-11-22 23:00:30.165 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column BookLoan_TABLE_loan_id not found in processed_data.
# 2024-11-22 23:00:30.166 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column REF__TABLE_book_id not found in processed_data.
# 2024-11-22 23:00:30.166 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:69 - Data reverse-converted by IntValueFormatter.
# 2024-11-22 23:00:30.166 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:164 - Data reverse-converting by DatetimeFormatter...
# 2024-11-22 23:00:30.167 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:166 - parameters : ['Student_TABLE_date_of_birth', 'Submission_TABLE_submission_date', 'BookLoan_TABLE_return_date', 'BookLoan_TABLE_loan_date'], {'Student_TABLE_date_of_birth': '%Y-%m-%d', 'BookLoan_TABLE_return_date': '%Y-%m-%d', 'BookLoan_TABLE_loan_date': '%Y-%m-%d', 'Submission_TABLE_submission_date': '%Y-%m-%d %H:%M:%S'}
# 2024-11-22 23:00:30.177 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:220 - Column Submission_TABLE_submission_date not in processed data's column list!
# 2024-11-22 23:00:30.178 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:220 - Column BookLoan_TABLE_return_date not in processed data's column list!
# 2024-11-22 23:00:30.178 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:220 - Column BookLoan_TABLE_loan_date not in processed data's column list!
# 2024-11-22 23:00:30.179 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:172 - Data reverse-converted by DatetimeFormatter... Finished.
# 2024-11-22 23:00:30.179 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:107 - Data reverse-converted by ConstValueTransformer.
# 2024-11-22 23:00:30.179 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:86 - Data reverse-converted by PositiveNegativeFilter Start with Shape: (1500, 5).
# 2024-11-22 23:00:30.180 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:106 - Data reverse-converted by PositiveNegativeFilter with Output Shape: (1499, 5).
# 2024-11-22 23:00:30.182 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:65 - Data reverse-converted by ColumnOrderTransformer.
# Sampling:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2024-11-22 23:00:31.382 | INFO     | sdgx.data_processors.transformers.specific_combination:reverse_convert:117 - Reverse converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-11-22 23:00:31.383 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:230 - Reverse converting data using FixedCombinationTransformer...
# CTGAN Generated 1500 raw samples
# Recovered 1500 samples
# 2024-11-22 23:00:31.604 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:254 - Reverse converting data using FixedCombinationTransformer... Finished.
# 2024-11-22 23:00:31.606 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:165 - Data reverse-converted by NonValueTransformer.
# 2024-11-22 23:00:31.608 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:126 - Data reverse-converted by OutlierTransformer (No Action).
# 2024-11-22 23:00:31.855 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column REF__TABLE_library_id not found in processed_data.
# 2024-11-22 23:00:31.855 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column Enrollment_TABLE_course_id not found in processed_data.
# 2024-11-22 23:00:31.856 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column Enrollment_TABLE_enrollment_id not found in processed_data.
# 2024-11-22 23:00:31.858 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column BookLoan_TABLE_loan_id not found in processed_data.
# 2024-11-22 23:00:31.858 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:68 - Column REF__TABLE_book_id not found in processed_data.
# 2024-11-22 23:00:31.858 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:69 - Data reverse-converted by IntValueFormatter.
# 2024-11-22 23:00:31.859 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:164 - Data reverse-converting by DatetimeFormatter...
# 2024-11-22 23:00:31.861 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:166 - parameters : ['Student_TABLE_date_of_birth', 'Submission_TABLE_submission_date', 'BookLoan_TABLE_return_date', 'BookLoan_TABLE_loan_date'], {'Student_TABLE_date_of_birth': '%Y-%m-%d', 'BookLoan_TABLE_return_date': '%Y-%m-%d', 'BookLoan_TABLE_loan_date': '%Y-%m-%d', 'Submission_TABLE_submission_date': '%Y-%m-%d %H:%M:%S'}
# 2024-11-22 23:00:31.861 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:220 - Column Student_TABLE_date_of_birth not in processed data's column list!
# 2024-11-22 23:00:31.862 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:220 - Column BookLoan_TABLE_return_date not in processed data's column list!
# 2024-11-22 23:00:31.863 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:220 - Column BookLoan_TABLE_loan_date not in processed data's column list!
# 2024-11-22 23:00:31.864 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:172 - Data reverse-converted by DatetimeFormatter... Finished.
# 2024-11-22 23:00:31.864 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:107 - Data reverse-converted by ConstValueTransformer.
# 2024-11-22 23:00:31.865 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:86 - Data reverse-converted by PositiveNegativeFilter Start with Shape: (1500, 6).
# 2024-11-22 23:00:31.866 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:106 - Data reverse-converted by PositiveNegativeFilter with Output Shape: (1489, 6).
# 2024-11-22 23:00:31.867 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:65 - Data reverse-converted by ColumnOrderTransformer.

# %%
for k in data:
    print(k, len(data[k]))
# Out:
# BookLoan 1000
# Book 1000
# Library 1000
# Student 1000
# Enrollment 1000
# Submission 1000

# %%
data["BookLoan"]
# Out:
#      loan_id  book_id  student_id   loan_date return_date
# 0       3930     3930        6387  2023-11-15  2025-01-21
# 1       2789     2789        5641  2024-09-27  2025-01-01
# 2       2131     2131        8284  2024-03-02  2025-04-18
# 3       9763     9763         588  2024-06-13  2025-09-01
# 4       3702     3702        7016  2024-01-05  2025-08-23
# ..       ...      ...         ...         ...         ...
# 995     8018     8018        6998  2024-03-01  2024-12-03
# 996     6361     6361        3582  2024-05-10  2025-10-07
# 997     1170     1170        4413  2024-02-12  2025-05-03
# 998     7594     7594        3072  2024-02-11  2025-08-17
# 999     4242     4242        9788  2024-02-03  2025-09-21
#
# [1000 rows x 5 columns]

# %%
s1 = (data["BookLoan"]["student_id"])

# %%
s2 = (data["Student"]["student_id"])

# %%
s1.equals(s2)
# Out:
# True

# %%
model.evaluate(x_args, data)
# Out:
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fwallace@collier-schmidt.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value allenjohn@obrien.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value larsonmalik@schmidt.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value andrea32@acosta.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michaelmcdaniel@lester.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wsimpson@ellis-moore.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hgilbert@nelson.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tevans@foley-thompson.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value adrian51@mills.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value thomaslewis@davidson-serrano.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value delacruzeric@lewis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value guypowell@ramirez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rosalescarrie@hughes-murray.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mary45@martin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value destinytaylor@hampton.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value carl01@watson-burke.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value terriwilliams@johnson-wilson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value erin83@joseph.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ericmoran@moore.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value anthony81@washington.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ofranklin@martin-hawkins.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nancymiller@klein.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value gonzalezrobert@boyd.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robinsonlori@jackson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wyattblack@williams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jonathan39@cabrera-ortiz.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jessica27@bates.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value umunoz@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value vgarcia@vasquez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nrobinson@allen.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brian13@jimenez.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value daniel06@wells-francis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tonylamb@crawford-castro.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value lmoore@acevedo.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value vryan@harris.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wangkathleen@valentine-lewis.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cmontoya@collins.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value uramirez@adams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jperez@mcdaniel.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jmason@price.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value delacruzkelsey@wheeler-lindsey.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value donald74@li.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ewilliams@hall.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value davismegan@murray.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sjackson@sanders.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value randallpearson@christian.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cdavis@mitchell-gilbert.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value morganwinters@payne.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value briankennedy@pittman.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value crystalhendrix@newton.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value flong@valenzuela-krause.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bakerjoseph@diaz.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value joshua66@medina.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value randall21@luna-schneider.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value matthew48@heath-flores.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value christopherfrey@jackson-mathis.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hedwards@lozano.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rwatkins@graham.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value damon40@solis-sanders.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mileswesley@thompson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rharrison@byrd.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ngordon@chang.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ynorton@velazquez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rachelcoleman@perkins.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zbrown@martinez.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value andrewbarnett@mendoza.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value dsanford@garner-ryan.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brandistevens@watkins.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value huntercraig@haynes-silva.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value james88@williams-williams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value danielmcdonald@kennedy.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value martinezconnor@brown.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zkirk@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robertsashley@jensen.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ethan22@moses.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value curtismorris@rodriguez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sharon20@garza-james.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value williamsjeffrey@jimenez.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fbond@warner.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value doylemelissa@kelley.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value linda38@evans.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kennethgibson@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value millerjanet@galvan-johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value phillip12@nichols.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value schultzrobin@murphy-barrett.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jamiemcmillan@richards.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value timothy90@stevenson-sanders.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value murphyjoann@maynard.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value uvalentine@gallegos.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value blakeangela@hubbard.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fcox@ross.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value douglascharles@smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value pjones@hill-russell.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value reginacampbell@blair.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value maryjohnson@romero.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jennifer16@jones-lin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brandonbrown@carrillo.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value joyce57@taylor.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value david33@ramirez.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value munozcaitlin@allen.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kimberlythompson@jackson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sarah03@sweeney.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value phernandez@scott.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mitchelldavid@trevino.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fwalker@gay-dennis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nross@cantrell.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jacob30@palmer-stone.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jonathandixon@cook-mcdaniel.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hansonjennifer@ray.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value david78@porter-norton.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rvilla@parker.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jaclyn99@marshall.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wgordon@price-holloway.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value justinmiller@johnson.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hamiltonshannon@phillips-anderson.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value david02@goodman.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zacharyjacobson@harvey.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nwilliams@myers.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value phester@rasmussen.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value urodriguez@torres-young.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value monica02@knight-johnson.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value uwright@thomas.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value anthony53@baldwin-knight.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value angela07@nichols.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brittany39@west-hanson.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value joshua70@evans-taylor.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brandypayne@mcbride.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value elester@lane.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value crystalbradley@goodman.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value chentara@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jeffreysimmons@morales.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value edwardjackson@cameron.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value melissamccarthy@beltran.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mckenziestephanie@anderson-gordon.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bsmith@obrien.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value pricestanley@jackson-rodriguez.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jonathantaylor@caldwell.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nicholas43@hughes.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kellimcgee@williamson-sanchez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zcastillo@allen.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michael95@mcconnell.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value harveyerin@kennedy.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cummingstimothy@long.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value leachmorgan@davis-fernandez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robert27@hill.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value joshuabooth@taylor.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brenda27@lane.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value harrisonemily@sutton-patterson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value browndustin@moore-copeland.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brownandrea@weaver.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sierragraves@gray-williams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value peterjohnson@hernandez.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michaelmartinez@daugherty-clark.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value johndouglas@lambert.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rnewton@thompson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value snyderwilliam@conner.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value baileydonald@joyce.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value perryyolanda@george-daniel.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value karafigueroa@johnson-nelson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value theresahawkins@hawkins-martin.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value elizabeth99@robinson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value shawn03@maldonado.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value leecindy@richardson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ujackson@hicks-smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michelle68@nichols-perkins.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value holly33@chambers.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qmartinez@taylor.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value john09@crane-butler.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value victoria27@thompson.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sbridges@carr.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value randolphwilliam@powell.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sawyerrussell@williamson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qbennett@vega.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value johnsonedward@sanchez-williams.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wolfeeric@lawrence.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value juan12@santos.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value griffinjoshua@smith-parker.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jorgefrancis@brandt.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value marybaldwin@miller.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value williamsmichael@wright.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value johnvargas@barber.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value joseph73@clements.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ataylor@doyle.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value darleneharris@smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value thompsondana@phillips.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jonathantate@barry.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value janicehull@thomas.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value angela01@morris.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jasonbrown@nunez-oconnor.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ugentry@stewart-moses.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zclark@caldwell.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tiffany43@buck.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value davenportnicholas@wagner-aguirre.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jasonvega@garcia.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tkhan@simpson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value youngmichael@wang-franklin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zcruz@shepard.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sean09@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mgarza@cantu.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value angel18@clarke.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value thomasmiller@richardson-gonzalez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nicoleroberts@macias-stone.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value millerjohn@singh-thompson.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rossjeffrey@alvarez-casey.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value samantha91@collins.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value williamsalazar@thompson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kelly57@leach.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brendaroberson@miller.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# ...
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jeffreyherrera@young.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value swhite@shaffer.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value baldwinbradley@richardson-adams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value lhoffman@avery.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tina94@martinez.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value vasquezjonathan@gonzales-manning.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value gonzalesbenjamin@dunn.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value gutierrezmichael@jenkins-clarke.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qsingh@jones.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value emily70@boone-stephens.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value grantjose@garcia.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michaelwilliams@smith-phelps.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jonesjames@barnes-bush.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value goodmanlindsay@stone.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sballard@cruz-white.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value shart@gray.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value agarcia@anderson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fmathews@mayo.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kennedysydney@jenkins.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wigginslisa@newman-shaffer.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jacobcox@powers.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value perkinsdennis@smith-hernandez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value xdelgado@mitchell.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jackford@johnson-burton.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value lmiller@short-clark.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value escobaralicia@marshall.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value alicia07@byrd-dixon.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value stephen67@adams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value elizabethproctor@collier.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ppatel@roberts.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zrush@phillips-ferguson.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value christopher43@morales-nixon.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value chelsea66@sullivan.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hodom@evans-johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qsmall@mccarthy.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value yhill@morse-rivera.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jodyroberts@smith-foster.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bberry@osborne.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mitchell39@pearson.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value aimeewise@ayala-aguilar.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value murphycharles@freeman-lopez.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value xdavis@matthews.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value karnold@werner.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value carrie96@berry.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value deleonmitchell@castro.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value vanderson@mercado.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bondjake@kelly-mason.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hhunter@mora.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value acarr@koch.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value floresjeff@craig.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value patricia61@fernandez-hopkins.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value stephanie77@ingram-carlson.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value gsanders@nguyen.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ashley13@williams.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value elizabeth36@ruiz-martinez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robin75@davis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value lori82@contreras.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value andrewevans@hernandez.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value christopheralvarez@thompson-campbell.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hullamy@armstrong.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fgray@hill.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value xroberts@acevedo.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value vcook@mack.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robinsonjacob@wilson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rebeccawillis@hardy.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mariaalvarez@moore.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value carol28@cardenas-jones.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value james12@osborne.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# 0.8614
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value  in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# (0.9228000000000001, 0.8)
