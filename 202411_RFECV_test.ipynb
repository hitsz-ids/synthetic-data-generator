# %%
from mycode.multi_rfe_ctgan import MultiTableRfecvCTGAN
from mycode import dataset
from mycode.testcode import Xargs

db_path = dataset.DatabaseTest.path_10k
db_level = db_path[db_path.rfind("/")+1:db_path.rfind(".db")]
table_level = '6'
x_args = Xargs.XArgs.tables_6
from mycode.dataset import XMetaBuilder

model = MultiTableRfecvCTGAN(db_path=db_path, x_args=x_args)
model.init(meta_builder=XMetaBuilder(x_args))
model.to_training
# Out:
# 2024-11-22 19:38:50.186 | INFO     | mycode.multi_rfe_ctgan:__init__:62 - Using data processors: ['nonvaluetransformer', 'outliertransformer', 'emailgenerator', 'chnpiigenerator', 'intvalueformatter', 'datetimeformatter', 'constvaluetransformer', 'emptytransformer', 'columnordertransformer']
# 2024-11-22 19:38:50.584 | INFO     | sdgx.data_models.metadata:from_dataloader:294 - Inspecting metadata...
# 10000 10000 10000 10000 10159 12338
# 12338 lines x 23 columns
# 2024-11-22 19:38:53.738 | INFO     | sdgx.data_models.metadata:update_primary_key:508 - Primary Key updated: set().
# 2024-11-22 19:38:53.757 | INFO     | sdgx.data_processors.transformers.nan:fit:71 - NonValueTransformer Fitted.
# 2024-11-22 19:38:53.758 | INFO     | sdgx.data_processors.transformers.nan:fit:87 - NonValueTransformer get int columns: {'Submission_TABLE_assignment_id', 'REF__TABLE_student_id', 'REF__TABLE_library_id', 'Submission_TABLE_submission_id', 'BookLoan_TABLE_loan_id', 'Enrollment_TABLE_course_id', 'Enrollment_TABLE_enrollment_id', 'REF__TABLE_book_id'}.
# 2024-11-22 19:38:53.758 | INFO     | sdgx.data_processors.transformers.nan:fit:96 - NonValueTransformer get float columns: set().
# 2024-11-22 19:38:53.759 | INFO     | sdgx.data_processors.transformers.nan:fit:101 - NonValueTransformer get column list from metadata: ['BookLoan_TABLE_loan_id', 'REF__TABLE_book_id', 'REF__TABLE_student_id', 'BookLoan_TABLE_loan_date', 'BookLoan_TABLE_return_date', 'Book_TABLE_title', 'Book_TABLE_author', 'Book_TABLE_isbn', 'REF__TABLE_library_id', 'Library_TABLE_name', 'Library_TABLE_location', 'Student_TABLE_name', 'Student_TABLE_email', 'Student_TABLE_date_of_birth', 'Student_TABLE_major', 'Enrollment_TABLE_enrollment_id', 'Enrollment_TABLE_course_id', 'Enrollment_TABLE_semester', 'Enrollment_TABLE_grade', 'Submission_TABLE_submission_id', 'Submission_TABLE_assignment_id', 'Submission_TABLE_submission_date', 'Submission_TABLE_grade'].
# 2024-11-22 19:38:53.759 | INFO     | sdgx.data_processors.transformers.outlier:fit:70 - OutlierTransformer Fitted.
# 2024-11-22 19:38:53.760 | INFO     | sdgx.data_processors.formatters.int:fit:40 - IntValueFormatter Fitted.
# 2024-11-22 19:38:53.761 | INFO     | sdgx.data_processors.formatters.datetime:fit:77 - DatetimeFormatter Fitted.
# 2024-11-22 19:38:53.761 | INFO     | sdgx.data_processors.transformers.const:fit:49 - ConstValueTransformer Fitted.
# 2024-11-22 19:38:53.762 | INFO     | sdgx.data_processors.transformers.empty:fit:54 - EmptyTransformer Fitted.
# 2024-11-22 19:38:53.762 | INFO     | sdgx.data_processors.transformers.column_order:fit:41 - ColumnOrderTransformer Fitted.
# 2024-11-22 19:38:53.763 | INFO     | mycode.multi_rfe_ctgan:_data_preprocess:113 - Fitted 9 data processors in  0.023060083389282227s.
# 2024-11-22 19:38:53.763 | INFO     | mycode.multi_rfe_ctgan:_data_preprocess:126 - Initializing processed data loader...
# 2024-11-22 19:38:53.776 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-11-22 19:38:53.786 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-11-22 19:38:53.787 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-11-22 19:38:53.810 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-11-22 19:38:53.816 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-11-22 19:38:53.817 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# {'datetime': ['Submission_TABLE_submission_date'], 'time': []}
# metadata.int_columns={'Submission_TABLE_assignment_id', 'REF__TABLE_student_id', 'REF__TABLE_library_id', 'Submission_TABLE_submission_id', 'BookLoan_TABLE_loan_id', 'Enrollment_TABLE_course_id', 'Enrollment_TABLE_enrollment_id', 'REF__TABLE_book_id'}
# metadata.float_columns=set()
# metadata.const_columns=set()
# metadata.bool_columns=set()
# metadata.discrete_columns={'Library_TABLE_name', 'Book_TABLE_author', 'Book_TABLE_isbn', 'Student_TABLE_email', 'Enrollment_TABLE_semester', 'Student_TABLE_major', 'Enrollment_TABLE_grade', 'Student_TABLE_name', 'Library_TABLE_location', 'Submission_TABLE_grade', 'Book_TABLE_title'}
# 2024-11-22 19:38:54.049 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-11-22 19:38:54.050 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-11-22 19:38:54.052 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-11-22 19:38:54.052 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-11-22 19:38:54.053 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-11-22 19:38:54.053 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-11-22 19:38:54.054 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-11-22 19:38:54.110 | INFO     | sdgx.data_processors.transformers.nan:convert:110 - Converting data using NonValueTransformer...
# 2024-11-22 19:38:54.116 | INFO     | sdgx.data_processors.transformers.nan:convert:130 - Converting data using NonValueTransformer... Finished.
# 2024-11-22 19:38:54.116 | INFO     | sdgx.data_processors.transformers.outlier:convert:84 - Converting data using OutlierTransformer...
# 2024-11-22 19:38:54.124 | INFO     | sdgx.data_processors.transformers.outlier:convert:106 - Converting data using OutlierTransformer... Finished.
# 2024-11-22 19:38:54.125 | INFO     | sdgx.data_processors.formatters.int:convert:50 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-11-22 19:38:54.126 | INFO     | sdgx.data_processors.formatters.datetime:convert:99 - Converting data using DatetimeFormatter...
# 2024-11-22 19:38:54.177 | INFO     | sdgx.data_processors.formatters.datetime:convert:105 - Converting data using DatetimeFormatter... Finished.
# 2024-11-22 19:38:54.179 | INFO     | sdgx.data_processors.transformers.const:convert:69 - Converting data using ConstValueTransformer...
# 2024-11-22 19:38:54.179 | INFO     | sdgx.data_processors.transformers.const:convert:77 - Converting data using ConstValueTransformer... Finished.
# 2024-11-22 19:38:54.180 | INFO     | sdgx.data_processors.transformers.empty:convert:72 - Converting data using EmptyTransformer...
# 2024-11-22 19:38:54.180 | INFO     | sdgx.data_processors.transformers.empty:convert:76 - Converting data using EmptyTransformer... Finished (No action).
# 2024-11-22 19:38:54.181 | INFO     | sdgx.data_processors.transformers.column_order:convert:51 - Converting data using ColumnOrderTransformer...
# 2024-11-22 19:38:54.182 | INFO     | sdgx.data_processors.transformers.column_order:convert:52 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-11-22 19:38:54.201 | INFO     | mycode.multi_rfe_ctgan:_data_preprocess:132 - Initialized processed data loader in 0.4373466968536377s
# C:\Users\Elvin\Desktop\GitHub\synthetic-data-generator\mycode\multi_rfe_ctgan.py:92: UserWarning: Detected columns deleting by data processors, we will attach original data to train RFECV.
#   warnings.warn("Detected columns deleting by data processors, we will attach original data to train RFECV.")
# Choosing Cols:   0%|          | 0/22 [00:00<?, ?it/s]
# [<mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x2ab8853abf0>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x2ab929cac50>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x2ab929ca0e0>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x2ab929ca0b0>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x2ab929ca1a0>,
#  <mycode.multi_rfe_ctgan.RFECV_CTGANTrainingData at 0x2ab929cbf70>]

# %%
for i in range(len(model.to_training)):
    tbn = model.to_training[i].table_name
    if model.to_training[i].tables is None:
        print(tbn)
        continue
    print(tbn, len(model.multi_x_join.origin_tables[tbn].columns),
    len(model.to_training[i].tables.columns),
          {
              k: len(v) for k, v in model.to_training[i].target_column_name_selected_map.items()
          },model.to_training[i].tables.columns)
# Out:
# BookLoan 5 16 {'BookLoan_TABLE_loan_date': 4, 'BookLoan_TABLE_loan_id': 3, 'REF__TABLE_student_id': 8} Index(['Submission_TABLE_assignment_id', 'BookLoan_TABLE_loan_date',
#        'Submission_TABLE_submission_date', 'REF__TABLE_library_id',
#        'Student_TABLE_major', 'Enrollment_TABLE_course_id',
#        'BookLoan_TABLE_return_date', 'Student_TABLE_date_of_birth',
#        'Library_TABLE_name', 'REF__TABLE_student_id',
#        'Submission_TABLE_submission_id', 'BookLoan_TABLE_loan_id',
#        'Student_TABLE_name', 'Library_TABLE_location',
#        'Enrollment_TABLE_enrollment_id', 'REF__TABLE_book_id'],
#       dtype='object')
# Book 5 8 {'Book_TABLE_author': 7} Index(['REF__TABLE_library_id', 'Book_TABLE_author', 'Book_TABLE_isbn',
#        'Enrollment_TABLE_semester', 'Enrollment_TABLE_grade',
#        'Submission_TABLE_grade', 'Book_TABLE_title', 'REF__TABLE_book_id'],
#       dtype='object')
# Library
# Student 5 4 {} Index(['REF__TABLE_student_id', 'Student_TABLE_major', 'Student_TABLE_name',
#        'Student_TABLE_date_of_birth'],
#       dtype='object')
# Enrollment
# Submission

# %%
model.fit()
# Out:
# 2024-11-22 19:39:57.333 | INFO     | mycode.multi_rfe_ctgan:_fit_argument_table_ctgan:340 - Fitting RFE-CTGAN model on table BookLoan...
# 2024-11-22 19:39:57.380 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:248 - Fitting model's transformer...
# Preparing data:   0%|          | 0/16 [00:00<?, ?it/s]
# 2024-11-22 19:40:04.816 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:250 - Transforming data...
# Transforming data:   0%|          | 0/16 [00:00<?, ?it/s]
# 2024-11-22 19:40:09.884 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:253 - Sampling data.
# 2024-11-22 19:40:09.886 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:258 - Initialize Generator.
# 2024-11-22 19:40:09.888 | INFO     | sdgx.models.ml.single_table.ctgan:fit:223 - CTGAN prefit finished, start CTGAN training.
# 2024-11-22 19:40:09.889 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:276 - Fit using data_size:12338, data_dim: 136.
# [ColumnTransformInfo(column_name='Submission_TABLE_assignment_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='BookLoan_TABLE_loan_date', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Submission_TABLE_submission_date', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='REF__TABLE_library_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Student_TABLE_major', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Enrollment_TABLE_course_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='BookLoan_TABLE_return_date', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Student_TABLE_date_of_birth', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Library_TABLE_name', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='REF__TABLE_student_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Submission_TABLE_submission_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='BookLoan_TABLE_loan_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Student_TABLE_name', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Library_TABLE_location', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Enrollment_TABLE_enrollment_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='REF__TABLE_book_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softma ...
# 2024-11-22 19:40:10.522 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:303 - Starting model training, epochs: 1
# Fitting batches:   0%|          | 0/24 [00:00<?, ?it/s]
# 2024-11-22 19:40:11.959 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:384 - Epoch 1, Loss G: -0.1936, Loss D:  0.2034, Time:  1.4360
# 2024-11-22 19:40:11.960 | INFO     | sdgx.models.ml.single_table.ctgan:fit:225 - CTGAN training finished.
# 2024-11-22 19:40:11.961 | INFO     | mycode.multi_rfe_ctgan:_fit_argument_table_ctgan:340 - Fitting RFE-CTGAN model on table Book...
# 2024-11-22 19:40:12.004 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:248 - Fitting model's transformer...
# data_dim: 136, time: 14.63s
# Preparing data:   0%|          | 0/8 [00:00<?, ?it/s]
# 2024-11-22 19:40:13.342 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:250 - Transforming data...
# Transforming data:   0%|          | 0/8 [00:00<?, ?it/s]
# 2024-11-22 19:40:16.131 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:253 - Sampling data.
# 2024-11-22 19:40:16.144 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:258 - Initialize Generator.
# 2024-11-22 19:40:16.148 | INFO     | sdgx.models.ml.single_table.ctgan:fit:223 - CTGAN prefit finished, start CTGAN training.
# 2024-11-22 19:40:16.149 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:276 - Fit using data_size:12338, data_dim: 57.
# 2024-11-22 19:40:16.150 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:303 - Starting model training, epochs: 1
# [ColumnTransformInfo(column_name='REF__TABLE_library_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Book_TABLE_author', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Book_TABLE_isbn', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Enrollment_TABLE_semester', column_type='discrete', transform=OneHotEncoder(), output_info=[SpanInfo(dim=20, activation_fn='softmax')], output_dimensions=20), ColumnTransformInfo(column_name='Enrollment_TABLE_grade', column_type='discrete', transform=OneHotEncoder(), output_info=[SpanInfo(dim=6, activation_fn='softmax')], output_dimensions=6), ColumnTransformInfo(column_name='Submission_TABLE_grade', column_type='discrete', transform=OneHotEncoder(), output_info=[SpanInfo(dim=6, activation_fn='softmax')], output_dimensions=6), ColumnTransformInfo(column_name='Book_TABLE_title', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='REF__TABLE_book_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11)]
# Fitting batches:   0%|          | 0/24 [00:00<?, ?it/s]
# 2024-11-22 19:40:17.152 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:384 - Epoch 1, Loss G:  2.0700, Loss D:  0.1150, Time:  1.0008
# 2024-11-22 19:40:17.154 | INFO     | sdgx.models.ml.single_table.ctgan:fit:225 - CTGAN training finished.
# 2024-11-22 19:40:17.154 | INFO     | mycode.multi_rfe_ctgan:_fit_argument_table_ctgan:340 - Fitting RFE-CTGAN model on table Student...
# 2024-11-22 19:40:17.182 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:248 - Fitting model's transformer...
# data_dim: 57, time: 5.19s
# Preparing data:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-11-22 19:40:18.386 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:250 - Transforming data...
# Transforming data:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-11-22 19:40:20.646 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:253 - Sampling data.
# 2024-11-22 19:40:20.647 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:258 - Initialize Generator.
# 2024-11-22 19:40:20.649 | INFO     | sdgx.models.ml.single_table.ctgan:fit:223 - CTGAN prefit finished, start CTGAN training.
# 2024-11-22 19:40:20.650 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:276 - Fit using data_size:12338, data_dim: 24.
# 2024-11-22 19:40:20.651 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:303 - Starting model training, epochs: 1
# [ColumnTransformInfo(column_name='REF__TABLE_student_id', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11), ColumnTransformInfo(column_name='Student_TABLE_major', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Student_TABLE_name', column_type='discrete', transform=LabelEncoder(order_by='alphabetical'), output_info=[SpanInfo(dim=1, activation_fn='liner')], output_dimensions=1), ColumnTransformInfo(column_name='Student_TABLE_date_of_birth', column_type='continuous', transform=ClusterBasedNormalizer(model_missing_values=True), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11)]
# Fitting batches:   0%|          | 0/24 [00:00<?, ?it/s]
# 2024-11-22 19:40:21.254 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:384 - Epoch 1, Loss G: -0.0271, Loss D:  0.0580, Time:  0.6014
# 2024-11-22 19:40:21.255 | INFO     | sdgx.models.ml.single_table.ctgan:fit:225 - CTGAN training finished.
# data_dim: 24, time: 4.1s

# %%
data = model.sample(10000)
# Out:
# Sampling:   0%|          | 0/10000 [00:00<?, ?it/s]
# Sampling batches:   0%|          | 0/25 [00:00<?, ?it/s]
# Inverse transforming:   0%|          | 0/16 [00:00<?, ?it/s]
# 2024-11-22 19:41:01.905 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:155 - Data reverse-converted by NonValueTransformer.
# 2024-11-22 19:41:01.907 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:120 - Data reverse-converted by OutlierTransformer (No Action).
# 2024-11-22 19:41:03.976 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:66 - Data reverse-converted by IntValueFormatter.
# 2024-11-22 19:41:03.977 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:155 - Data reverse-converting by DatetimeFormatter...
# 2024-11-22 19:41:03.977 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:157 - parameters : ['Submission_TABLE_submission_date', 'Student_TABLE_date_of_birth', 'BookLoan_TABLE_loan_date', 'BookLoan_TABLE_return_date'], {'Student_TABLE_date_of_birth': '%Y-%m-%d', 'BookLoan_TABLE_loan_date': '%Y-%m-%d', 'BookLoan_TABLE_return_date': '%Y-%m-%d', 'Submission_TABLE_submission_date': '%Y-%m-%d %H:%M:%S'}
# 2024-11-22 19:41:04.134 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:163 - Data reverse-converted by DatetimeFormatter... Finished.
# 2024-11-22 19:41:04.135 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:103 - Data reverse-converted by ConstValueTransformer.
# 2024-11-22 19:41:04.135 | INFO     | sdgx.data_processors.transformers.empty:reverse_convert:98 - Data reverse-converted by EmptyTransformer.
# 2024-11-22 19:41:04.138 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:62 - Data reverse-converted by ColumnOrderTransformer.
# Sampling:   0%|          | 0/10000 [00:00<?, ?it/s]
# Sampling batches:   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Inverse transforming:   0%|          | 0/8 [00:00<?, ?it/s]
# 2024-11-22 19:41:35.571 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:155 - Data reverse-converted by NonValueTransformer.
# 2024-11-22 19:41:35.573 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:120 - Data reverse-converted by OutlierTransformer (No Action).
# 2024-11-22 19:41:37.722 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Submission_TABLE_assignment_id not found in processed_data.
# 2024-11-22 19:41:37.722 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column REF__TABLE_student_id not found in processed_data.
# 2024-11-22 19:41:37.723 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Submission_TABLE_submission_id not found in processed_data.
# 2024-11-22 19:41:37.724 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column BookLoan_TABLE_loan_id not found in processed_data.
# 2024-11-22 19:41:37.724 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Enrollment_TABLE_course_id not found in processed_data.
# 2024-11-22 19:41:37.724 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Enrollment_TABLE_enrollment_id not found in processed_data.
# 2024-11-22 19:41:37.726 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:66 - Data reverse-converted by IntValueFormatter.
# 2024-11-22 19:41:37.726 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:155 - Data reverse-converting by DatetimeFormatter...
# 2024-11-22 19:41:37.727 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:157 - parameters : ['Submission_TABLE_submission_date', 'Student_TABLE_date_of_birth', 'BookLoan_TABLE_loan_date', 'BookLoan_TABLE_return_date'], {'Student_TABLE_date_of_birth': '%Y-%m-%d', 'BookLoan_TABLE_loan_date': '%Y-%m-%d', 'BookLoan_TABLE_return_date': '%Y-%m-%d', 'Submission_TABLE_submission_date': '%Y-%m-%d %H:%M:%S'}
# 2024-11-22 19:41:37.728 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:211 - Column Submission_TABLE_submission_date not in processed data's column list!
# 2024-11-22 19:41:37.729 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:211 - Column Student_TABLE_date_of_birth not in processed data's column list!
# 2024-11-22 19:41:37.729 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:211 - Column BookLoan_TABLE_loan_date not in processed data's column list!
# 2024-11-22 19:41:37.730 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:211 - Column BookLoan_TABLE_return_date not in processed data's column list!
# 2024-11-22 19:41:37.730 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:163 - Data reverse-converted by DatetimeFormatter... Finished.
# 2024-11-22 19:41:37.731 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:103 - Data reverse-converted by ConstValueTransformer.
# 2024-11-22 19:41:37.731 | INFO     | sdgx.data_processors.transformers.empty:reverse_convert:98 - Data reverse-converted by EmptyTransformer.
# 2024-11-22 19:41:37.733 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:62 - Data reverse-converted by ColumnOrderTransformer.
# Sampling:   0%|          | 0/10000 [00:00<?, ?it/s]
# Sampling batches:   0%|          | 0/25 [00:00<?, ?it/s]
# Inverse transforming:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-11-22 19:41:42.695 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:155 - Data reverse-converted by NonValueTransformer.
# 2024-11-22 19:41:42.697 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:120 - Data reverse-converted by OutlierTransformer (No Action).
# 2024-11-22 19:41:45.189 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Submission_TABLE_assignment_id not found in processed_data.
# 2024-11-22 19:41:45.190 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column REF__TABLE_library_id not found in processed_data.
# 2024-11-22 19:41:45.191 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Submission_TABLE_submission_id not found in processed_data.
# 2024-11-22 19:41:45.191 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column BookLoan_TABLE_loan_id not found in processed_data.
# 2024-11-22 19:41:45.192 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Enrollment_TABLE_course_id not found in processed_data.
# 2024-11-22 19:41:45.192 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column Enrollment_TABLE_enrollment_id not found in processed_data.
# 2024-11-22 19:41:45.193 | ERROR    | sdgx.data_processors.formatters.int:reverse_convert:65 - Column REF__TABLE_book_id not found in processed_data.
# 2024-11-22 19:41:45.194 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:66 - Data reverse-converted by IntValueFormatter.
# 2024-11-22 19:41:45.194 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:155 - Data reverse-converting by DatetimeFormatter...
# 2024-11-22 19:41:45.196 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:157 - parameters : ['Submission_TABLE_submission_date', 'Student_TABLE_date_of_birth', 'BookLoan_TABLE_loan_date', 'BookLoan_TABLE_return_date'], {'Student_TABLE_date_of_birth': '%Y-%m-%d', 'BookLoan_TABLE_loan_date': '%Y-%m-%d', 'BookLoan_TABLE_return_date': '%Y-%m-%d', 'Submission_TABLE_submission_date': '%Y-%m-%d %H:%M:%S'}
# 2024-11-22 19:41:45.198 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:211 - Column Submission_TABLE_submission_date not in processed data's column list!
# 2024-11-22 19:41:45.253 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:211 - Column BookLoan_TABLE_loan_date not in processed data's column list!
# 2024-11-22 19:41:45.254 | ERROR    | sdgx.data_processors.formatters.datetime:convert_timestamp_to_datetime:211 - Column BookLoan_TABLE_return_date not in processed data's column list!
# 2024-11-22 19:41:45.254 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:163 - Data reverse-converted by DatetimeFormatter... Finished.
# 2024-11-22 19:41:45.257 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:103 - Data reverse-converted by ConstValueTransformer.
# 2024-11-22 19:41:45.258 | INFO     | sdgx.data_processors.transformers.empty:reverse_convert:98 - Data reverse-converted by EmptyTransformer.
# 2024-11-22 19:41:45.260 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:62 - Data reverse-converted by ColumnOrderTransformer.

# %%
for k in data:
    print(k, len(data[k]))
# Out:
# BookLoan 10000
# Book 10000
# Library 10000
# Student 10000
# Enrollment 10000
# Submission 10000

# %%
data["Book"]
# Out:
#       book_id                                      title             author  \
# 0        8008                           Us quickly race.     Nicole Griffin
# 1        2398                       Step finish someone.  Kristina Crawford
# 2        7219                            Top morning up.     Lori Jones DDS
# 3        8440                                  Marriage.         Laura Yang
# 4        1364                       Usually wide finish.        Jason Knapp
# ...       ...                                        ...                ...
# 9995     5984                          Seek season sure.   Jennifer Ballard
# 9996     3613                                  Yourself.      Lindsey Lopez
# 9997     6838                               Prove along.     Fernando Parks
# 9998     8810                                  Yourself.      Jessica Boyer
# 9999     3457  Somebody environmental international him.        Kevin Rojas
#
#                    isbn  library_id
# 0     978-1-4174-6291-9        4009
# 1     978-0-640-82229-3        2817
# 2     978-0-9833674-1-3        9384
# 3     978-0-7722-7443-4        1277
# 4     978-0-642-14620-5        1232
# ...                 ...         ...
# 9995  978-1-08-054267-3        1731
# 9996  978-0-374-94315-8        5377
# 9997  978-0-642-15383-8        2732
# 9998  978-0-392-89003-8        2735
# 9999  978-0-677-16537-0        7979
#
# [10000 rows x 5 columns]

# %%
s1 = (data["BookLoan"]["student_id"])

# %%
s2 = (data["Student"]["student_id"])

# %%
s1.equals(s2)
# Out:
# True

# %%
model.evaluate(x_args, data)
# Out:
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kristin29@powers.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value stevewalker@parker.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kimberlydavis@mullen.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jamesvazquez@garza-zhang.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value reidryan@mccarty.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kelly18@phillips.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hward@doyle.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value luis89@smith.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qsantiago@martinez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value johnnygordon@meyer.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value daniel44@thomas-andersen.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ogoodman@santos-nelson.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value estevens@horton-webb.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value pamela42@mann-gutierrez.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value vaughanwilliam@pratt-sandoval.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bellkayla@clark.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jensenvalerie@wu.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ydavila@sullivan.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value lisaestes@durham.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nicoleramirez@watson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fedwards@barber-ramirez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nguerra@payne-sanders.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value riceamber@jimenez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nkelly@lucas-cortez.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value trogers@lang.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value petersonmichael@branch-hansen.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value herreracatherine@smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rmartin@hernandez-matthews.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value olivia14@ruiz-bryant.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zacharyburke@taylor.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brandonfranklin@chambers-castillo.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bbutler@campbell.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kgarcia@pearson-fisher.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value shane87@james.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value urogers@grimes.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ewood@gibbs-baxter.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value khanna@barrett.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value gvaldez@murray.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value muelleraustin@foster.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value phillipsjesse@todd.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bettywalker@evans.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value shellypowell@castaneda-newman.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value johnwalsh@williams-mckee.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kimberlylogan@gillespie.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value austinkelley@duran.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value richard04@cobb-faulkner.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jackson17@cunningham.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rodriguezkyle@webb.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hawkinsrobert@brown.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jbell@black.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hmendoza@king.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michael10@bennett.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value leetina@bartlett.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value markanderson@brown.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tiffany12@robinson.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value villarrealkimberly@adams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jennifer27@giles.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qschwartz@thomas.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fbrewer@brown.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hgoodwin@willis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value barnold@williams.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value copelandelizabeth@rowland.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value autumn17@lewis-harding.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value abrooks@watson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tara63@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value costanicholas@tyler.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value louisleblanc@thompson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value christophermurphy@goodwin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value adrianhoward@vang-wang.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value matthewmclean@thompson-curtis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value harold56@tyler.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jesus78@gomez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value terryjoshua@beck.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value patriciamason@moreno-whitaker.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ajohnson@harvey-martin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nbuckley@sanchez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kelleytyler@sanders.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value elaineroberts@raymond.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value garciabryan@fernandez.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bushstuart@clark.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value iturner@cain-anderson.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value irojas@green.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jamesalexis@hanson.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jonathancisneros@dean.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value stephenfloyd@harvey-perez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hughesjustin@rogers.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kkoch@clark.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value juliajackson@neal-miller.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robinlopez@hernandez-bullock.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value feliciawaller@romero.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nwilson@pope.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value paul53@oconnor.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cbond@murphy.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value amanda07@hardin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cynthiarivera@turner-johnson.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nscott@thomas.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value melissa58@palmer.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mckinneymaureen@ramos.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value samuel13@warner.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value huberkimberly@harper.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value randymccoy@moore.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value troydowns@harris-jefferson.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ldavis@wade-smith.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bennettsara@johnson-greene.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bruce58@wright.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cisnerosjeffrey@martin-rivera.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value watsonjonathon@benjamin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value dustin29@glenn.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value damon48@smith.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cmanning@campos-lee.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wilcoxmelissa@weiss-waters.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value yesenia85@haley.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jasoncunningham@cardenas.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ijames@schroeder.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value moralesgary@jackson-davidson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value careyangela@sanchez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value amysanchez@thomas.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value melissagonzalez@pena-garcia.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value scott86@nelson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value petersshannon@vincent.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fosterkathy@perez.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value amberfletcher@miller.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value carlyknox@lewis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kristinduke@craig.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value steven08@skinner.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value charlesweaver@stewart-weber.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kimolson@martinez.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value joshuaturner@salazar.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value nicole04@daniels.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rebecca90@walker-evans.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rjohnson@bailey.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value adriancrawford@singh-lin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value santiagobrianna@ritter-johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value johnsoncolleen@walker-sanders.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zmitchell@gallagher.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hsandoval@bentley.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value johncampbell@wright.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kaitlyn33@davis.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value pjames@roberts.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value richard98@francis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value carriejohnson@west-lane.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value simpsonalexander@brown.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jamie25@wood.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value theresa83@berry-clark.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value carolynjuarez@powell.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value catherinelynch@parks-james.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value meghanmejia@villarreal.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zsmith@davis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value victoria58@schneider.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value petersoncarla@torres.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value thorntonkaren@goodwin.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value glenda07@stewart.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rasmussenjohn@wright.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value timothychavez@king.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value dianadonovan@shaffer-weaver.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value khunter@atkinson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value david50@jackson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ncoleman@pollard.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jamesgarrett@lee-rosales.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value leslie97@duarte.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qtaylor@branch-livingston.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jessicaayers@ellis-harris.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value patrick36@floyd.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ncoleman@ortiz-ruiz.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value elizabethsmith@jennings.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bridgetanthony@cannon.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kristinellison@rogers.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ioconnor@bailey.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value laurenjohnson@smith.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bdecker@watson.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kellymyers@mcintosh.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zmoon@levy.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value theresa98@taylor.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value zacharycox@arellano.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value catherine40@davis.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brittany08@hernandez.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wrightnicholas@lee.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value downsangel@carr-hansen.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michaelcoleman@lang-lowe.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value warrenleslie@hernandez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jonesmiguel@jackson.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value shawnbenton@kirby-smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value flowersgerald@smith-brown.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value courtney94@zimmerman.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value bbrown@ward-parker.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brandonking@johnston-hunt.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jsimmons@malone-holmes.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jacob54@mcclure.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sarah36@reed.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value alane@smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value madams@harris.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kimberly78@welch-adams.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kingmichael@ramirez-lawson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michael55@bush.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wallacejason@williams-vincent.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tharrington@rodgers-miller.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value walleradam@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value arthurbutler@rios.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value schwartztravis@murphy-boone.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value stacymiles@wagner.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cisnerosdaniel@dickson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value valeriebates@patterson.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jeremy21@cruz.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value xdiaz@parker.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value john82@powell.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value pattersonstephanie@johnson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value tammy28@barber-warren.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ashleycameron@banks-christensen.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# ...
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value lisa33@weiss-ashley.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rachel89@fields.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rachel13@wilson-jones.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value juandavis@thomas-johnson.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value christopher08@clark.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value amanda15@frazier.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value simmonsvirginia@mckee.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wooddiana@castillo.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value omayo@fuller-nguyen.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value sarahreeves@anderson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ihicks@avila.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value katiemartinez@byrd.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kristinaruiz@long.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rangeljames@smith.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ivaldez@williams.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value osmith@wolf.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value joshua15@saunders-jenkins.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value warrenchristian@horton.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jacobcochran@bolton.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michael06@coleman.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value cody73@haney-jones.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value vargasmatthew@hamilton.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michele49@johnson-lowe.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value mark07@stewart.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value msherman@brewer-waters.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value osuarez@king.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hughesmichael@norman.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value peter86@munoz.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jaymelendez@vega.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jessicaphillips@johnson.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value brentgreen@smith-bender.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value xkeith@bradshaw.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value john83@miller.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robinsondana@estes.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value norristimothy@parrish-sanchez.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jeffery16@hernandez.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value patriciaallison@mccall-brown.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value harriskristy@griffith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value christopherromero@johnson-miller.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ryanjoseph@adams-wood.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ryan73@smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jcrawford@stanley.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value glennjulie@smith.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value williamwalters@alexander.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value qowens@bradford.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value randolphjames@mcdonald-west.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value adrianbutler@giles-dunlap.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value berrymatthew@freeman.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value crystal33@evans-wood.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value timothy69@parsons-green.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value ericabailey@hamilton.info in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jessica97@williams.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value wilsondeborah@underwood.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value william32@barrett.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value robertanderson@murray.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value washingtonamy@wilson.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value darren78@mendoza.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value rspencer@brewer-hernandez.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value anthonylewis@barber-marsh.net in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value estradajoshua@coleman.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value andersondaniel@perry-miller.biz in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value michaelcarter@bullock.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jamesgeorge@clark.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value hopkinsbailey@smith-chen.org in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value kevin74@hicks.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value phillipsdaniel@rice-phillips.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value fcline@mullins.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value jessehayes@brown.com in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# 0.8325605809547185
# C:\Users\Elvin\.conda\envs\synthetic-data-generator\lib\site-packages\sdmetrics\utils.py:67: UserWarning: Unexpected value  in synthetic data.
#   warnings.warn(f'Unexpected value {value} in synthetic data.')
# (0.8469394152438344, 0.8181817466656025)
